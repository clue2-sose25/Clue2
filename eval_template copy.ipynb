# %%
# %load_ext autoreload
# %autoreload 1
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %aimport exv2.experiment_results 

import seaborn as sns
import pandas as pd


pd.set_option('display.max_columns', None)
sns.set_theme(rc={'figure.figsize':(12, 6)})

# %%
MANUAL="data/2024-06-22_11-26-02"
NEW="data/2024-07-12_23-44-59"
# KARL_LOCAL = "data/data/*"
exr = exv2.experiment_results.ExperimentResults(NEW, load_stats_history=True) # type: ignore
RUN_VARS = exv2.experiment_results.ExperimentResults.RUN_VARS # type: ignore

assert("loadgenerator" not in (list(exr.pods['name'].unique())))
assert("unkown" not in (list(exr.pods['instance'].unique())))
# Out:
# WARNING:root:loaded 32869 datapoints with 1720 problems
# 'NODES'
#       instance     observation_time     collection_time  cpu_usage  \
# 0   ise-knode1  2024-07-13 00:27:55 2024-07-13 00:27:55   0.354000
# 1       sm-gpu  2024-07-13 00:27:55 2024-07-13 00:27:55   0.376000
# 2   ise-knode2  2024-07-13 00:27:55 2024-07-13 00:27:55   0.078667
# 3   ise-knode3  2024-07-13 00:27:55 2024-07-13 00:27:55   0.043000
# 4  ise-kmaster  2024-07-13 00:27:55 2024-07-13 00:27:55   0.227000
#
#    memory_usage  network_usage  wattage  num_processes  wattage_kepler  \
# 0      0.266282       0.968456        0             14        0.100233
# 1      0.145627       0.147770       46             14        0.112867
# 2      0.173816       0.008959        0              7        0.000000
# 3      0.169221       0.007718        0              5        0.000000
# 4      0.260791       0.369886        0             10        0.000000
#
#    wattage_scaph  wattage_auxilary  temperture      exp_workload  \
# 0       0.118384          0.000329         0.0  exp_scale_rampup
# 1      14.388329          0.046836        67.0  exp_scale_rampup
# 2       0.000000          0.000000         0.0  exp_scale_rampup
# 3       0.000000          0.000000         0.0  exp_scale_rampup
# 4       0.000000          0.000000         0.0  exp_scale_rampup
#
#                            exp_branch            exp_start         run_start  \
# 0  dbopt_feature_db-optimization_full  2024-07-12_23-44-59  13_07_2024_00_27
# 1  dbopt_feature_db-optimization_full  2024-07-12_23-44-59  13_07_2024_00_27
# 2  dbopt_feature_db-optimization_full  2024-07-12_23-44-59  13_07_2024_00_27
# 3  dbopt_feature_db-optimization_full  2024-07-12_23-44-59  13_07_2024_00_27
# 4  dbopt_feature_db-optimization_full  2024-07-12_23-44-59  13_07_2024_00_27
#
#   run_iteration                                                run  \
# 0             1  dbopt_feature_db-optimization_full_exp_scale_r...
# 1             1  dbopt_feature_db-optimization_full_exp_scale_r...
# 2             1  dbopt_feature_db-optimization_full_exp_scale_r...
# 3             1  dbopt_feature_db-optimization_full_exp_scale_r...
# 4             1  dbopt_feature_db-optimization_full_exp_scale_r...
#
#                                                 urun  wattage_kepler_zscore  \
# 0  2024-07-12_23-44-59_dbopt_feature_db-optimizat...              -0.601188
# 1  2024-07-12_23-44-59_dbopt_feature_db-optimizat...              -0.593469
# 2  2024-07-12_23-44-59_dbopt_feature_db-optimizat...              -0.662430
# 3  2024-07-12_23-44-59_dbopt_feature_db-optimizat...              -0.662430
# 4  2024-07-12_23-44-59_dbopt_feature_db-optimizat...              -0.662430
#
#    wattage_scaph_zscore  cpu_usage_zscore  memory_usage_zscore  \
# 0             -0.706027         -0.542861             0.891447
# 1              0.858179         -0.518250            -1.177420
# 2             -0.719004         -0.850876            -0.694063
# 3             -0.719004         -0.890776            -0.772862
# 4             -0.719004         -0.684936             0.797282
#
#    network_usage_zscore run_time  wattage_estimation
# 0             -0.452381   0 days                 NaN
# 1             -0.524863   0 days           48.756737
# 2             -0.537123   0 days                 NaN
# 3             -0.537232   0 days                 NaN
# 4             -0.505246   0 days                 NaN
# 'PODS'
#       collection_time     observation_time                    name  namespace  \
# 0 2024-07-13 00:27:55  2024-07-13 00:27:55     teastore-registry-0  tea-bench
# 1 2024-07-13 00:27:55  2024-07-13 00:27:55        teastore-webui-0  tea-bench
# 2 2024-07-13 00:27:55  2024-07-13 00:27:55        teastore-webui-2  tea-bench
# 3 2024-07-13 00:27:55  2024-07-13 00:27:55  teastore-recommender-0  tea-bench
# 4 2024-07-13 00:27:55  2024-07-13 00:27:55           teastore-db-0  tea-bench
#
#    cpu_usage  memory_usage  network_usage    instance  wattage_kepler  \
# 0        0.0    268.414976       0.001149      sm-gpu           364.4
# 1        0.0   1065.846784       0.000000      sm-gpu           364.4
# 2        0.0      0.000000       0.000000  ise-knode6             0.0
# 3        0.0    913.473536       0.000792  ise-knode1            11.0
# 4        0.0    102.414336       0.000000      sm-gpu           182.2
#
#    wattage_scaph      exp_workload                          exp_branch  \
# 0       0.030023  exp_scale_rampup  dbopt_feature_db-optimization_full
# 1       0.034427  exp_scale_rampup  dbopt_feature_db-optimization_full
# 2       0.000000  exp_scale_rampup  dbopt_feature_db-optimization_full
# 3       0.000566  exp_scale_rampup  dbopt_feature_db-optimization_full
# 4       0.000801  exp_scale_rampup  dbopt_feature_db-optimization_full
#
#              exp_start         run_start run_iteration  \
# 0  2024-07-12_23-44-59  13_07_2024_00_27             1
# 1  2024-07-12_23-44-59  13_07_2024_00_27             1
# 2  2024-07-12_23-44-59  13_07_2024_00_27             1
# 3  2024-07-12_23-44-59  13_07_2024_00_27             1
# 4  2024-07-12_23-44-59  13_07_2024_00_27             1
#
#                                                  run  \
# 0  dbopt_feature_db-optimization_full_exp_scale_r...
# 1  dbopt_feature_db-optimization_full_exp_scale_r...
# 2  dbopt_feature_db-optimization_full_exp_scale_r...
# 3  dbopt_feature_db-optimization_full_exp_scale_r...
# 4  dbopt_feature_db-optimization_full_exp_scale_r...
#
#                                                 urun  wattage_kepler_zscore  \
# 0  2024-07-12_23-44-59_dbopt_feature_db-optimizat...               1.069523
# 1  2024-07-12_23-44-59_dbopt_feature_db-optimizat...               1.069523
# 2  2024-07-12_23-44-59_dbopt_feature_db-optimizat...              -0.831343
# 3  2024-07-12_23-44-59_dbopt_feature_db-optimizat...              -0.773962
# 4  2024-07-12_23-44-59_dbopt_feature_db-optimizat...               0.119090
#
#    wattage_scaph_zscore  cpu_usage_zscore  memory_usage_zscore  \
# 0             -0.306241         -0.556014            -0.991124
# 1             -0.299419         -0.556014             0.358592
# 2             -0.352756         -0.556014            -1.445437
# 3             -0.351880         -0.556014             0.100688
# 4             -0.351516         -0.556014            -1.272093
#
#    network_usage_zscore run_time              name_prefix  \
# 0             -0.334866   0 days     [teastore, registry]
# 1             -0.335424   0 days        [teastore, webui]
# 2             -0.335424   0 days        [teastore, webui]
# 3             -0.335040   0 days  [teastore, recommender]
# 4             -0.335424   0 days           [teastore, db]
#
#                pod_name
# 0     teastore-registry
# 1        teastore-webui
# 2        teastore-webui
# 3  teastore-recommender
# 4           teastore-db
# 'STATS'
#    Type                                               Name  Request Count  \
# 0   GET                   /tools.descartes.teastore.webui/           5173
# 1  POST                   /tools.descartes.teastore.webui/             12
# 2  POST               /tools.descartes.teastore.webui/cart            118
# 3  POST  /tools.descartes.teastore.webui/cartAction?add...              7
# 4  POST  /tools.descartes.teastore.webui/cartAction?add...              9
#
#    Failure Count  Median Response Time  Average Response Time  \
# 0           1580                2000.0           13230.944295
# 1             12                 810.0            1126.302226
# 2            118               11000.0            8778.079230
# 3              1                1400.0            2808.538882
# 4              0                 690.0             957.391041
#
#    Min Response Time  Max Response Time  Average Content Size  Requests/s  \
# 0           1.752267       83338.941411           6459.636961   14.374612
# 1         269.899631        3498.963863              0.000000    0.033345
# 2         174.109649       20796.444194              0.000000    0.327896
# 3         159.248762       13771.214250          23658.571429    0.019451
# 4         533.634839        2221.892640          28165.333333    0.025009
#
#    Failures/s    50%    66%    75%    80%    90%    95%    98%    99%  99.9%  \
# 0    4.390467   2000   5700  23000  27000  40000  74000  77000  78000  80000
# 1    0.033345    970   1500   1600   1600   1900   3500   3500   3500   3500
# 2    0.327896  11000  11000  12000  13000  15000  19000  19000  20000  21000
# 3    0.002779   1400   1500   1600   1600  14000  14000  14000  14000  14000
# 4    0.000000    690    710   1100   1500   2200   2200   2200   2200   2200
#
#    99.99%   100%      exp_workload                          exp_branch  \
# 0   83000  83000  exp_scale_rampup  dbopt_feature_db-optimization_full
# 1    3500   3500  exp_scale_rampup  dbopt_feature_db-optimization_full
# 2   21000  21000  exp_scale_rampup  dbopt_feature_db-optimization_full
# 3   14000  14000  exp_scale_rampup  dbopt_feature_db-optimization_full
# 4    2200   2200  exp_scale_rampup  dbopt_feature_db-optimization_full
#
#              exp_start run_start run_iteration  \
# 0  2024-07-12_23-44-59                       1
# 1  2024-07-12_23-44-59                       1
# 2  2024-07-12_23-44-59                       1
# 3  2024-07-12_23-44-59                       1
# 4  2024-07-12_23-44-59                       1
#
#                                                  run  \
# 0  dbopt_feature_db-optimization_full_exp_scale_r...
# 1  dbopt_feature_db-optimization_full_exp_scale_r...
# 2  dbopt_feature_db-optimization_full_exp_scale_r...
# 3  dbopt_feature_db-optimization_full_exp_scale_r...
# 4  dbopt_feature_db-optimization_full_exp_scale_r...
#
#                                                 urun
# 0  2024-07-12_23-44-59_dbopt_feature_db-optimizat...
# 1  2024-07-12_23-44-59_dbopt_feature_db-optimizat...
# 2  2024-07-12_23-44-59_dbopt_feature_db-optimizat...
# 3  2024-07-12_23-44-59_dbopt_feature_db-optimizat...
# 4  2024-07-12_23-44-59_dbopt_feature_db-optimizat...

# %%
display("NODES") # capslock = markdown fuer arme
display(exr.nodes.head())

display("PODS")
display(exr.pods.head())

display("STATS")
display(exr.stats.head())
