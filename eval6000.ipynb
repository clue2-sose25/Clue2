# %%
# %load_ext autoreload
# %autoreload 1
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %aimport exv2.experiment_results 

import seaborn as sns
import pandas as pd


pd.set_option('display.max_columns', None)
sns.set_theme(rc={'figure.figsize':(12, 6)})

# %%
MANUAL="data/2024-06-22_11-26-02"
KARL_LOCAL = "data/data/*"
exr = exv2.experiment_results.ExperimentResults(MANUAL, load_stats_history=True)

assert("loadgenerator" not in (list(exr.pods['name'].unique())))
assert("unkown" not in (list(exr.pods['instance'].unique())))

display("NODES") # capslock = markdown fuer arme
display(exr.nodes.head())

display("PODS")
display(exr.pods.head())

display("STATS")
display(exr.stats.head())
# Out:
# WARNING:root:loaded 27387 datapoints with 1480 problems
# 'NODES'
#       instance     observation_time     collection_time  cpu_usage  \
# 0   ise-knode6  2024-06-22 17:20:08 2024-06-22 17:20:08   0.211333
# 1   ise-knode1  2024-06-22 17:20:08 2024-06-22 17:20:08   0.541667
# 2   ise-knode2  2024-06-22 17:20:08 2024-06-22 17:20:08   0.045333
# 3       sm-gpu  2024-06-22 17:20:08 2024-06-22 17:20:08   0.783000
# 4  ise-kmaster  2024-06-22 17:20:08 2024-06-22 17:20:08   0.215695
#
#    memory_usage  network_usage  wattage  num_processes  wattage_kepler  \
# 0      0.095585       0.481627       43             17        2.186310
# 1      0.182418       0.700743        0             15        0.925400
# 2      0.214710       0.005633        0              4        0.000000
# 3      0.147023       0.144862       47             13        1.955767
# 4      0.243538       0.351827        0             10        0.000000
#
#    wattage_scaph  wattage_auxilary     exp_workload             exp_branch  \
# 0      15.414111          0.179994  exp_scale_fixed  baseline_vanilla_full
# 1       0.646936          0.002297  exp_scale_fixed  baseline_vanilla_full
# 2       0.000000          0.000000  exp_scale_fixed  baseline_vanilla_full
# 3      25.190738          0.087316  exp_scale_fixed  baseline_vanilla_full
# 4       0.000000          0.000000  exp_scale_fixed  baseline_vanilla_full
#
#              exp_start         run_start run_iteration  \
# 0  2024-06-22_11-26-02  22_06_2024_17_19             0
# 1  2024-06-22_11-26-02  22_06_2024_17_19             0
# 2  2024-06-22_11-26-02  22_06_2024_17_19             0
# 3  2024-06-22_11-26-02  22_06_2024_17_19             0
# 4  2024-06-22_11-26-02  22_06_2024_17_19             0
#
#                                        run  \
# 0  baseline_vanilla_full_exp_scale_fixed_0
# 1  baseline_vanilla_full_exp_scale_fixed_0
# 2  baseline_vanilla_full_exp_scale_fixed_0
# 3  baseline_vanilla_full_exp_scale_fixed_0
# 4  baseline_vanilla_full_exp_scale_fixed_0
#
#                                                 urun  wattage_kepler_zscore  \
# 0  2024-06-22_11-26-02_baseline_vanilla_full_exp_...               1.994813
# 1  2024-06-22_11-26-02_baseline_vanilla_full_exp_...               0.483910
# 2  2024-06-22_11-26-02_baseline_vanilla_full_exp_...              -0.624963
# 3  2024-06-22_11-26-02_baseline_vanilla_full_exp_...               1.718561
# 4  2024-06-22_11-26-02_baseline_vanilla_full_exp_...              -0.624963
#
#    wattage_scaph_zscore  cpu_usage_zscore  memory_usage_zscore  \
# 0              1.270836         -0.235299            -1.624192
# 1             -0.621532          0.628392            -0.050070
# 2             -0.704435         -0.669323             0.535321
# 3              2.523681          1.259383            -0.691704
# 4             -0.704435         -0.223893             1.057924
#
#    network_usage_zscore run_time  wattage_estimation
# 0             -0.209184   0 days           43.598945
# 1             -0.141023   0 days                 NaN
# 2             -0.357253   0 days                 NaN
# 3             -0.313942   0 days           52.973591
# 4             -0.249561   0 days                 NaN
# 'PODS'
#       collection_time     observation_time                    name  namespace  \
# 3 2024-06-22 17:20:08  2024-06-22 17:20:08  teastore-recommender-0  tea-bench
# 4 2024-06-22 17:20:08  2024-06-22 17:20:08     teastore-registry-0  tea-bench
# 5 2024-06-22 17:20:08  2024-06-22 17:20:08  teastore-persistence-0  tea-bench
# 6 2024-06-22 17:20:08  2024-06-22 17:20:08           teastore-db-0  tea-bench
# 7 2024-06-22 17:20:08  2024-06-22 17:20:08        teastore-webui-0  tea-bench
#
#    cpu_usage  memory_usage  network_usage    instance  wattage_kepler  \
# 3   0.251781    741.728256       0.003534  ise-knode1            39.2
# 4   0.036085    257.609728       0.002238      sm-gpu           584.2
# 5   0.118234    634.490880       0.041169      sm-gpu           584.2
# 6   0.005193    105.746432       0.023312  ise-knode1            19.6
# 7   0.380162   1084.213248       0.001105  ise-knode1            39.2
#
#    wattage_scaph     exp_workload             exp_branch            exp_start  \
# 3       0.022606  exp_scale_fixed  baseline_vanilla_full  2024-06-22_11-26-02
# 4       0.073937  exp_scale_fixed  baseline_vanilla_full  2024-06-22_11-26-02
# 5       0.966112  exp_scale_fixed  baseline_vanilla_full  2024-06-22_11-26-02
# 6       0.001648  exp_scale_fixed  baseline_vanilla_full  2024-06-22_11-26-02
# 7       0.028619  exp_scale_fixed  baseline_vanilla_full  2024-06-22_11-26-02
#
#           run_start run_iteration                                      run  \
# 3  22_06_2024_17_19             0  baseline_vanilla_full_exp_scale_fixed_0
# 4  22_06_2024_17_19             0  baseline_vanilla_full_exp_scale_fixed_0
# 5  22_06_2024_17_19             0  baseline_vanilla_full_exp_scale_fixed_0
# 6  22_06_2024_17_19             0  baseline_vanilla_full_exp_scale_fixed_0
# 7  22_06_2024_17_19             0  baseline_vanilla_full_exp_scale_fixed_0
#
#                                                 urun  wattage_kepler_zscore  \
# 3  2024-06-22_11-26-02_baseline_vanilla_full_exp_...              -0.819818
# 4  2024-06-22_11-26-02_baseline_vanilla_full_exp_...               1.681126
# 5  2024-06-22_11-26-02_baseline_vanilla_full_exp_...               1.681126
# 6  2024-06-22_11-26-02_baseline_vanilla_full_exp_...              -0.909761
# 7  2024-06-22_11-26-02_baseline_vanilla_full_exp_...              -0.819818
#
#    wattage_scaph_zscore  cpu_usage_zscore  memory_usage_zscore  \
# 3             -0.245699          1.067623            -0.055059
# 4              0.030275         -0.207586            -0.901770
# 5              4.826909          0.278082            -0.242614
# 6             -0.358373         -0.390219            -1.167375
# 7             -0.213372          1.826614             0.543939
#
#    network_usage_zscore run_time              name_prefix
# 3             -0.177846   0 days  [teastore, recommender]
# 4             -0.179835   0 days     [teastore, registry]
# 5             -0.120053   0 days  [teastore, persistence]
# 6             -0.147475   0 days           [teastore, db]
# 7             -0.181576   0 days        [teastore, webui]
# 'STATS'
#    Type                                               Name  Request Count  \
# 0   GET                   /tools.descartes.teastore.webui/            264
# 1  POST  /tools.descartes.teastore.webui/cartAction?add...              1
# 2  POST  /tools.descartes.teastore.webui/cartAction?add...              1
# 3  POST  /tools.descartes.teastore.webui/cartAction?add...              1
# 4  POST  /tools.descartes.teastore.webui/cartAction?add...              2
#
#    Failure Count  Median Response Time  Average Response Time  \
# 0              5            250.000000             775.648768
# 1              1            302.024068             302.024068
# 2              0            875.573960             875.573960
# 3              0           1339.182832            1339.182832
# 4              0           1195.405550            1192.179824
#
#    Min Response Time  Max Response Time  Average Content Size  Requests/s  \
# 0          16.135793       12721.670115           8868.598485    3.200687
# 1         302.024068         302.024068           7002.000000    0.012124
# 2         875.573960         875.573960          25908.000000    0.012124
# 3        1339.182832        1339.182832          27095.000000    0.012124
# 4        1188.954097        1195.405550          26777.500000    0.024248
#
#    Failures/s   50%   66%   75%   80%   90%   95%   98%    99%  99.9%  99.99%  \
# 0    0.060619   250   310   370   430   660  5000  9200  11000  13000   13000
# 1    0.012124   300   300   300   300   300   300   300    300    300     300
# 2    0.000000   880   880   880   880   880   880   880    880    880     880
# 3    0.000000  1300  1300  1300  1300  1300  1300  1300   1300   1300    1300
# 4    0.000000  1200  1200  1200  1200  1200  1200  1200   1200   1200    1200
#
#     100%     exp_workload             exp_branch            exp_start  \
# 0  13000  exp_scale_fixed  baseline_vanilla_full  2024-06-22_11-26-02
# 1    300  exp_scale_fixed  baseline_vanilla_full  2024-06-22_11-26-02
# 2    880  exp_scale_fixed  baseline_vanilla_full  2024-06-22_11-26-02
# 3   1300  exp_scale_fixed  baseline_vanilla_full  2024-06-22_11-26-02
# 4   1200  exp_scale_fixed  baseline_vanilla_full  2024-06-22_11-26-02
#
#   run_start run_iteration                                      run  \
# 0                       0  baseline_vanilla_full_exp_scale_fixed_0
# 1                       0  baseline_vanilla_full_exp_scale_fixed_0
# 2                       0  baseline_vanilla_full_exp_scale_fixed_0
# 3                       0  baseline_vanilla_full_exp_scale_fixed_0
# 4                       0  baseline_vanilla_full_exp_scale_fixed_0
#
#                                                 urun
# 0  2024-06-22_11-26-02_baseline_vanilla_full_exp_...
# 1  2024-06-22_11-26-02_baseline_vanilla_full_exp_...
# 2  2024-06-22_11-26-02_baseline_vanilla_full_exp_...
# 3  2024-06-22_11-26-02_baseline_vanilla_full_exp_...
# 4  2024-06-22_11-26-02_baseline_vanilla_full_exp_...

# %%
sns.barplot(data=exr.absolute_requests_per_branch(), y="exp_branch", x="value", hue="variable", palette=["green", "red"])
# exr.absolute_requests_per_branch()
# Out:
# <Axes: xlabel='value', ylabel='exp_branch'>

# %%
sns.lineplot(data=exr.pods, x="run_time", y="cpu_usage", hue="exp_workload")
# Out:
# <Axes: xlabel='run_time', ylabel='cpu_usage'>

# %%
run_stats = exr.run_stats()
run_stats.head()
# Out:
#              exp_start             exp_branch       exp_workload  \
# 0  2024-06-22_11-26-02  baseline_vanilla_full    exp_scale_fixed
# 1  2024-06-22_11-26-02  baseline_vanilla_full    exp_scale_fixed
# 2  2024-06-22_11-26-02  baseline_vanilla_full  exp_scale_pausing
# 3  2024-06-22_11-26-02  baseline_vanilla_full  exp_scale_pausing
# 4  2024-06-22_11-26-02  baseline_vanilla_full   exp_scale_rampup
#
#   run_iteration  Request Count  Failure Count  Success Count  reliability  \
# 0             0           2983             33           2950     0.988937
# 1             1           2778             15           2763     0.994600
# 2             0            834              7            827     0.991607
# 3             1            646             41            605     0.936533
# 4             0          22355           6176          16179     0.723731
#
#          run_time  total_rps  success_rps
# 0 0 days 00:05:54   8.426554     8.333333
# 1 0 days 00:05:54   7.847458     7.805085
# 2 0 days 00:05:53   2.362606     2.342776
# 3 0 days 00:05:54   1.824859     1.709040
# 4 0 days 00:05:54  63.149718    45.703390

# %%
exr.pods['exp_workload'].unique()
# Out:
# array(['exp_scale_fixed', 'exp_scale_shaped', 'exp_scale_pausing',
#        'exp_scale_rampup'], dtype=object)

# %%
sns.barplot(data=exr.rps_per_branch(), x="value", y="exp_branch", hue="variable")
# Out:
# <Axes: xlabel='value', ylabel='exp_branch'>

# %%
e = exr.pods_energy()
kep = e['wattage_kepler'].sum()
sca = e['wattage_scaph'].sum()
ratio = kep/sca

display(kep, sca, ratio)
# Out:
# np.float64(1579054.1380500041)
# np.float64(502455.76511630614)
# np.float64(3.1426729429295968)

# %%
exr.pods_energy().head()
# Out:
#                                                                                              run_time  \
# exp_start           exp_branch                         exp_workload     run_iteration
# 2024-06-22_11-26-02 baseline_vanilla_full              exp_scale_fixed  0             0 days 00:05:54
#                                                                         1             0 days 00:05:54
#                                                        exp_scale_shaped 0             0 days 00:05:44
#                                                                         1             0 days 00:05:44
#                     dbopt_feature_db-optimization_full exp_scale_fixed  0             0 days 00:05:53
#
#                                                                                        wattage_kepler  \
# exp_start           exp_branch                         exp_workload     run_iteration
# 2024-06-22_11-26-02 baseline_vanilla_full              exp_scale_fixed  0                74941.400000
#                                                                         1                68367.893115
#                                                        exp_scale_shaped 0                54073.200000
#                                                                         1                68638.705722
#                     dbopt_feature_db-optimization_full exp_scale_fixed  0                83349.900000
#
#                                                                                        wattage_scaph  \
# exp_start           exp_branch                         exp_workload     run_iteration
# 2024-06-22_11-26-02 baseline_vanilla_full              exp_scale_fixed  0                2349.725575
#                                                                         1                2914.327073
#                                                        exp_scale_shaped 0                1036.678539
#                                                                         1                1585.423150
#                     dbopt_feature_db-optimization_full exp_scale_fixed  0                5791.567549
#
#                                                                                        cpu_usage  \
# exp_start           exp_branch                         exp_workload     run_iteration
# 2024-06-22_11-26-02 baseline_vanilla_full              exp_scale_fixed  0              21.877450
#                                                                         1              22.104514
#                                                        exp_scale_shaped 0              18.849225
#                                                                         1              16.647961
#                     dbopt_feature_db-optimization_full exp_scale_fixed  0              46.084394
#
#                                                                                         memory_usage  \
# exp_start           exp_branch                         exp_workload     run_iteration
# 2024-06-22_11-26-02 baseline_vanilla_full              exp_scale_fixed  0              218033.061888
#                                                                         1              281746.255872
#                                                        exp_scale_shaped 0              185692.778496
#                                                                         1              178125.533184
#                     dbopt_feature_db-optimization_full exp_scale_fixed  0              358914.054827
#
#                                                                                        wattage_kepler_avg  \
# exp_start           exp_branch                         exp_workload     run_iteration
# 2024-06-22_11-26-02 baseline_vanilla_full              exp_scale_fixed  0                    95428.976978
#                                                                         1                    78578.682347
#                                                        exp_scale_shaped 0                    75923.186939
#                                                                         1                    96374.345993
#                     dbopt_feature_db-optimization_full exp_scale_fixed  0                    72469.248030
#
#                                                                                        wattage_scaph_avg  \
# exp_start           exp_branch                         exp_workload     run_iteration
# 2024-06-22_11-26-02 baseline_vanilla_full              exp_scale_fixed  0                    2992.096595
#                                                                         1                    3349.583713
#                                                        exp_scale_shaped 0                    1455.581295
#                                                                         1                    2226.063525
#                     dbopt_feature_db-optimization_full exp_scale_fixed  0                    5035.525480
#
#                                                                                        cpu_usage_avg  \
# exp_start           exp_branch                         exp_workload     run_iteration
# 2024-06-22_11-26-02 baseline_vanilla_full              exp_scale_fixed  0                  27.858336
#                                                                         1                  25.405838
#                                                        exp_scale_shaped 0                  26.465851
#                                                                         1                  23.375097
#                     dbopt_feature_db-optimization_full exp_scale_fixed  0                  40.068451
#
#                                                                                        memory_usage_avg
# exp_start           exp_branch                         exp_workload     run_iteration
# 2024-06-22_11-26-02 baseline_vanilla_full              exp_scale_fixed  0                 277639.222692
#                                                                         1                 323825.242139
#                                                        exp_scale_shaped 0                 260727.819603
#                                                                         1                 250102.789450
#                     dbopt_feature_db-optimization_full exp_scale_fixed  0                 312060.742251

# %%
# comparing summing up all wattages (assuming they are per second) vs average watt per experiment times number of seconds

nrj = exr.pods_energy(energy_workloads=True).reset_index()
wcols = nrj.columns[nrj.columns.str.startswith('wattage')]
wcols

sns.barplot(
    data=nrj.melt(id_vars=exv2.experiment_results.ExperimentResults.RUN_VARS, value_vars=list(wcols)),
    x="exp_workload",
    y="value",
    hue="variable"
)
# Out:
# <Axes: xlabel='exp_workload', ylabel='value'>

# %%
exr.run_stats().merge(exr.runs_energy(), on=exv2.experiment_results.ExperimentResults.RUN_VARS)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 exr.run_stats().merge(exr.runs_energy(), on=exv2.experiment_results.ExperimentResults.RUN_VARS)
#
# AttributeError: 'ExperimentResults' object has no attribute 'runs_energy'

# %%
awesomepods = exr.pods
awesomepods = awesomepods[awesomepods['name'] != 'loadgenerator']
awesomepods = awesomepods[awesomepods['exp_branch'] == "baseline_vanilla_full"]
# awesomepods = awesomepods[awesomepods['exp_workload'] == "exp_scale_pausing"]
# exr.pods['name'].unique()
awesomepods['pod_name'] = awesomepods['name'].apply(lambda x: x[:-2])
# awesomepods = awesomepods[awesomepods['pod_name'] == "teastore-webui"]


podstime = awesomepods.groupby(['exp_workload', 'pod_name', 'run_time']).agg({"wattage_scaph": "mean", "wattage_kepler": "mean", "cpu_usage": "sum", 'name': 'nunique'})

podstime
# Out:
#                                                  wattage_scaph  \
# exp_workload     pod_name       run_time
# exp_scale_fixed  teastore-auth  0 days 00:00:00       0.543836
#                                 0 days 00:00:10       0.191457
#                                 0 days 00:00:20       0.113481
#                                 0 days 00:00:21       0.429368
#                                 0 days 00:00:31       0.271424
# ...                                                        ...
# exp_scale_shaped teastore-webui 0 days 00:05:23       0.000483
#                                 0 days 00:05:24       0.000386
#                                 0 days 00:05:33       0.000483
#                                 0 days 00:05:34       0.000386
#                                 0 days 00:05:44       0.000402
#
#                                                  wattage_kepler  cpu_usage  \
# exp_workload     pod_name       run_time
# exp_scale_fixed  teastore-auth  0 days 00:00:00      523.230817   0.325026
#                                 0 days 00:00:10      443.630817   0.093739
#                                 0 days 00:00:20      425.000000   0.153041
#                                 0 days 00:00:21      604.800000   0.093739
#                                 0 days 00:00:31      514.900000   0.577222
# ...                                                         ...        ...
# exp_scale_shaped teastore-webui 0 days 00:05:23       10.800000   0.056664
#                                 0 days 00:05:24       12.000000   0.057165
#                                 0 days 00:05:33       10.800000   0.000000
#                                 0 days 00:05:34       11.800000   0.057165
#                                 0 days 00:05:44       11.300000   0.117643
#
#                                                  name
# exp_workload     pod_name       run_time
# exp_scale_fixed  teastore-auth  0 days 00:00:00     1
#                                 0 days 00:00:10     1
#                                 0 days 00:00:20     1
#                                 0 days 00:00:21     1
#                                 0 days 00:00:31     1
# ...                                               ...
# exp_scale_shaped teastore-webui 0 days 00:05:23     1
#                                 0 days 00:05:24     1
#                                 0 days 00:05:33     1
#                                 0 days 00:05:34     1
#                                 0 days 00:05:44     1
#
# [1316 rows x 4 columns]

# %%
sns.lineplot(data=exr.nodes[exr.nodes['exp_workload'] == 'exp_scale_fixed'], x='run_time', y='wattage', hue='exp_branch')
# Out:
# <Axes: xlabel='run_time', ylabel='wattage'>

# %%
exr.nodes_energy()
# Out:
#                                                                                                 run_time  \
# exp_start           exp_branch                           exp_workload      run_iteration
# 2024-06-22_11-26-02 baseline_vanilla_full                exp_scale_fixed   0             0 days 00:05:54
#                                                                            1             0 days 00:05:54
#                                                          exp_scale_pausing 0             0 days 00:05:53
#                                                                            1             0 days 00:05:54
#                                                          exp_scale_rampup  0             0 days 00:05:54
#                                                                            1             0 days 00:05:55
#                                                          exp_scale_shaped  0             0 days 00:05:44
#                                                                            1             0 days 00:05:44
#                     dbopt_feature_db-optimization_full   exp_scale_fixed   0             0 days 00:05:53
#                                                                            1             0 days 00:05:54
#                                                          exp_scale_pausing 0             0 days 00:05:53
#                                                                            1             0 days 00:05:54
#                                                          exp_scale_rampup  0             0 days 00:05:54
#                                                                            1             0 days 00:05:53
#                                                          exp_scale_shaped  0             0 days 00:05:43
#                                                                            1             0 days 00:05:43
#                     jvm_jvm-impoove_full                 exp_scale_fixed   0             0 days 00:05:54
#                                                                            1             0 days 00:05:54
#                                                          exp_scale_pausing 0             0 days 00:05:53
#                                                                            1             0 days 00:05:53
#                                                          exp_scale_rampup  0             0 days 00:05:55
#                                                                            1             0 days 00:05:54
#                                                          exp_scale_shaped  0             0 days 00:05:44
#                                                                            1             0 days 00:05:43
#                     lessrec_feature_lessrecs_full        exp_scale_fixed   0             0 days 00:05:53
#                                                                            1             0 days 00:05:53
#                                                          exp_scale_pausing 0             0 days 00:05:54
#                                                                            1             0 days 00:05:54
#                                                          exp_scale_rampup  0             0 days 00:05:54
#                                                                            1             0 days 00:05:54
#                                                          exp_scale_shaped  0             0 days 00:05:43
#                                                                            1             0 days 00:05:44
#                     norec_feature_norecommendations_full exp_scale_fixed   0             0 days 00:05:54
#                                                                            1             0 days 00:05:54
#                                                          exp_scale_pausing 0             0 days 00:05:54
#                                                                            1             0 days 00:05:53
#                                                          exp_scale_rampup  0             0 days 00:05:54
#                                                                            1             0 days 00:05:54
#                                                          exp_scale_shaped  0             0 days 00:05:44
#                                                                            1             0 days 00:05:44
#                     obs_feature_object-storage_full      exp_scale_fixed   0             0 days 00:05:53
#                                                                            1             0 days 00:05:53
#                                                          exp_scale_pausing 0             0 days 00:05:53
#                                                                            1             0 days 00:05:53
#                                                          exp_scale_rampup  0             0 days 00:05:54
#                                                                            1             0 days 00:05:54
#                                                          exp_scale_shaped  0             0 days 00:05:43
#                                                                            1             0 days 00:05:43
#
#                                                                                           wattage_kepler  \
# exp_start           exp_branch                           exp_workload      run_iteration
# 2024-06-22_11-26-02 baseline_vanilla_full                exp_scale_fixed   0                  112.656352
#                                                                            1                  109.945755
#                                                          exp_scale_pausing 0                  109.500550
#                                                                            1                  148.208173
#                                                          exp_scale_rampup  0                  160.682597
#                                                                            1                  164.796423
#                                                          exp_scale_shaped  0                   98.177460
#                                                                            1                  101.988738
#                     dbopt_feature_db-optimization_full   exp_scale_fixed   0                  169.682151
#                                                                            1                  128.995004
#                                                          exp_scale_pausing 0                  104.663999
#                                                                            1                  169.021493
#                                                          exp_scale_rampup  0                  160.446588
#                                                                            1                  152.757559
#                                                          exp_scale_shaped  0                  101.338967
#                                                                            1                  112.307459
#                     jvm_jvm-impoove_full                 exp_scale_fixed   0                  105.343857
#                                                                            1                  107.182490
#                                                          exp_scale_pausing 0                  107.196881
#                                                                            1                   99.249962
#                                                          exp_scale_rampup  0                  227.833597
#                                                                            1                  224.508988
#                                                          exp_scale_shaped  0                  105.336733
#                                                                            1                  104.381167
#                     lessrec_feature_lessrecs_full        exp_scale_fixed   0                  128.466067
#                                                                            1                  111.438639
#                                                          exp_scale_pausing 0                  111.310848
#                                                                            1                  100.447800
#                                                          exp_scale_rampup  0                  237.820197
#                                                                            1                  226.766034
#                                                          exp_scale_shaped  0                  106.097385
#                                                                            1                  105.354766
#                     norec_feature_norecommendations_full exp_scale_fixed   0                  117.284713
#                                                                            1                  109.166712
#                                                          exp_scale_pausing 0                  131.613674
#                                                                            1                  101.087755
#                                                          exp_scale_rampup  0                  217.390851
#                                                                            1                  184.112062
#                                                          exp_scale_shaped  0                  109.311514
#                                                                            1                  103.304779
#                     obs_feature_object-storage_full      exp_scale_fixed   0                  133.280739
#                                                                            1                  143.614500
#                                                          exp_scale_pausing 0                  106.607576
#                                                                            1                  102.755000
#                                                          exp_scale_rampup  0                  117.582533
#                                                                            1                  136.911614
#                                                          exp_scale_shaped  0                  110.231700
#                                                                            1                  104.688751
#
#                                                                                           wattage_scaph  \
# exp_start           exp_branch                           exp_workload      run_iteration
# 2024-06-22_11-26-02 baseline_vanilla_full                exp_scale_fixed   0               1.187371e+05
#                                                                            1               1.146541e+05
#                                                          exp_scale_pausing 0               1.199888e+05
#                                                                            1               1.199910e+05
#                                                          exp_scale_rampup  0               1.393040e+05
#                                                                            1               1.280937e+05
#                                                          exp_scale_shaped  0               1.106188e+05
#                                                                            1               1.132253e+05
#                     dbopt_feature_db-optimization_full   exp_scale_fixed   0               1.257016e+05
#                                                                            1               1.236789e+07
#                                                          exp_scale_pausing 0               1.128073e+05
#                                                                            1               1.195115e+05
#                                                          exp_scale_rampup  0               1.379676e+05
#                                                                            1               1.350271e+05
#                                                          exp_scale_shaped  0               1.126602e+05
#                                                                            1               1.124207e+05
#                     jvm_jvm-impoove_full                 exp_scale_fixed   0               1.108301e+05
#                                                                            1               1.149101e+05
#                                                          exp_scale_pausing 0               1.150779e+05
#                                                                            1               1.076416e+05
#                                                          exp_scale_rampup  0               1.459602e+05
#                                                                            1               1.243771e+07
#                                                          exp_scale_shaped  0               1.145241e+05
#                                                                            1               1.146222e+05
#                     lessrec_feature_lessrecs_full        exp_scale_fixed   0               1.187415e+05
#                                                                            1               1.169368e+05
#                                                          exp_scale_pausing 0               1.198857e+05
#                                                                            1               1.106232e+05
#                                                          exp_scale_rampup  0               1.511159e+05
#                                                                            1               1.505216e+05
#                                                          exp_scale_shaped  0               1.133331e+05
#                                                                            1               1.158368e+05
#                     norec_feature_norecommendations_full exp_scale_fixed   0               1.213921e+05
#                                                                            1               1.163483e+05
#                                                          exp_scale_pausing 0               1.167524e+05
#                                                                            1               1.152968e+05
#                                                          exp_scale_rampup  0               1.485748e+05
#                                                                            1               1.417588e+05
#                                                          exp_scale_shaped  0               1.160278e+05
#                                                                            1               1.136196e+05
#                     obs_feature_object-storage_full      exp_scale_fixed   0               1.255904e+05
#                                                                            1               1.282647e+05
#                                                          exp_scale_pausing 0               1.107393e+05
#                                                                            1               1.142832e+05
#                                                          exp_scale_rampup  0               1.218017e+05
#                                                                            1               1.291817e+05
#                                                          exp_scale_shaped  0               1.172136e+05
#                                                                            1               1.157197e+05
#
#                                                                                           wattage  \
# exp_start           exp_branch                           exp_workload      run_iteration
# 2024-06-22_11-26-02 baseline_vanilla_full                exp_scale_fixed   0                 3363
#                                                                            1                 3342
#                                                          exp_scale_pausing 0                 3314
#                                                                            1                 3421
#                                                          exp_scale_rampup  0                 3763
#                                                                            1                 3563
#                                                          exp_scale_shaped  0                 3229
#                                                                            1                 3228
#                     dbopt_feature_db-optimization_full   exp_scale_fixed   0                 3472
#                                                                            1                 3387
#                                                          exp_scale_pausing 0                 3220
#                                                                            1                 3400
#                                                          exp_scale_rampup  0                 3665
#                                                                            1                 3568
#                                                          exp_scale_shaped  0                 3240
#                                                                            1                 3133
#                     jvm_jvm-impoove_full                 exp_scale_fixed   0                 3139
#                                                                            1                 3198
#                                                          exp_scale_pausing 0                 3281
#                                                                            1                 3099
#                                                          exp_scale_rampup  0                 3743
#                                                                            1                 3588
#                                                          exp_scale_shaped  0                 3234
#                                                                            1                 3283
#                     lessrec_feature_lessrecs_full        exp_scale_fixed   0                 3332
#                                                                            1                 3296
#                                                          exp_scale_pausing 0                 3387
#                                                                            1                 3391
#                                                          exp_scale_rampup  0                 3886
#                                                                            1                 3902
#                                                          exp_scale_shaped  0                 3159
#                                                                            1                 3337
#                     norec_feature_norecommendations_full exp_scale_fixed   0                 3378
#                                                                            1                 3312
#                                                          exp_scale_pausing 0                 3459
#                                                                            1                 3233
#                                                          exp_scale_rampup  0                 3902
#                                                                            1                 3715
#                                                          exp_scale_shaped  0                 3269
#                                                                            1                 3265
#                     obs_feature_object-storage_full      exp_scale_fixed   0                 3414
#                                                                            1                 3540
#                                                          exp_scale_pausing 0                 3268
#                                                                            1                 3240
#                                                          exp_scale_rampup  0                 3374
#                                                                            1                 3549
#                                                          exp_scale_shaped  0                 3329
#                                                                            1                 3339
#
#                                                                                           wattage_kepler_avg  \
# exp_start           exp_branch                           exp_workload      run_iteration
# 2024-06-22_11-26-02 baseline_vanilla_full                exp_scale_fixed   0                      184.631243
#                                                                            1                      180.188876
#                                                          exp_scale_pausing 0                      178.952287
#                                                                            1                      242.896728
#                                                          exp_scale_rampup  0                      263.340923
#                                                                            1                      278.584429
#                                                          exp_scale_shaped  0                      160.824030
#                                                                            1                      167.067266
#                     dbopt_feature_db-optimization_full   exp_scale_fixed   0                      277.304626
#                                                                            1                      211.408478
#                                                          exp_scale_pausing 0                      175.935199
#                                                                            1                      277.007447
#                                                          exp_scale_rampup  0                      262.954130
#                                                                            1                      249.645455
#                                                          exp_scale_shaped  0                      165.520312
#                                                                            1                      188.830678
#                     jvm_jvm-impoove_full                 exp_scale_fixed   0                      182.802575
#                                                                            1                      180.679055
#                                                          exp_scale_pausing 0                      175.187496
#                                                                            1                      171.741355
#                                                          exp_scale_rampup  0                      385.147271
#                                                                            1                      378.458008
#                                                          exp_scale_shaped  0                      172.551601
#                                                                            1                      170.489239
#                     lessrec_feature_lessrecs_full        exp_scale_fixed   0                      215.945340
#                                                                            1                      187.323045
#                                                          exp_scale_pausing 0                      182.426112
#                                                                            1                      164.622783
#                                                          exp_scale_rampup  0                      389.760878
#                                                                            1                      371.644334
#                                                          exp_scale_shaped  0                      178.389230
#                                                                            1                      172.581140
#                     norec_feature_norecommendations_full exp_scale_fixed   0                      192.216614
#                                                                            1                      178.912111
#                                                          exp_scale_pausing 0                      215.700188
#                                                                            1                      165.203599
#                                                          exp_scale_rampup  0                      356.279451
#                                                                            1                      301.739212
#                                                          exp_scale_shaped  0                      179.062670
#                                                                            1                      169.223066
#                     obs_feature_object-storage_full      exp_scale_fixed   0                      217.815281
#                                                                            1                      234.703326
#                                                          exp_scale_pausing 0                      174.224418
#                                                                            1                      167.928309
#                                                          exp_scale_rampup  0                      192.704707
#                                                                            1                      224.382923
#                                                          exp_scale_shaped  0                      180.045110
#                                                                            1                      170.991627
#
#                                                                                           wattage_scaph_avg  \
# exp_start           exp_branch                           exp_workload      run_iteration
# 2024-06-22_11-26-02 baseline_vanilla_full                exp_scale_fixed   0                   1.945970e+05
#                                                                            1                   1.879053e+05
#                                                          exp_scale_pausing 0                   1.960928e+05
#                                                                            1                   1.966519e+05
#                                                          exp_scale_rampup  0                   2.283038e+05
#                                                                            1                   2.165393e+05
#                                                          exp_scale_shaped  0                   1.812041e+05
#                                                                            1                   1.854738e+05
#                     dbopt_feature_db-optimization_full   exp_scale_fixed   0                   2.054289e+05
#                                                                            1                   2.026960e+07
#                                                          exp_scale_pausing 0                   1.896237e+05
#                                                                            1                   1.958661e+05
#                                                          exp_scale_rampup  0                   2.261135e+05
#                                                                            1                   2.206692e+05
#                                                          exp_scale_shaped  0                   1.840117e+05
#                                                                            1                   1.890210e+05
#                     jvm_jvm-impoove_full                 exp_scale_fixed   0                   1.923229e+05
#                                                                            1                   1.937056e+05
#                                                          exp_scale_pausing 0                   1.880672e+05
#                                                                            1                   1.862622e+05
#                                                          exp_scale_rampup  0                   2.467422e+05
#                                                                            1                   2.096643e+07
#                                                          exp_scale_shaped  0                   1.876014e+05
#                                                                            1                   1.872163e+05
#                     lessrec_feature_lessrecs_full        exp_scale_fixed   0                   1.995988e+05
#                                                                            1                   1.965651e+05
#                                                          exp_scale_pausing 0                   1.964793e+05
#                                                                            1                   1.812992e+05
#                                                          exp_scale_rampup  0                   2.476621e+05
#                                                                            1                   2.466882e+05
#                                                          exp_scale_shaped  0                   1.905552e+05
#                                                                            1                   1.897517e+05
#                     norec_feature_norecommendations_full exp_scale_fixed   0                   1.989482e+05
#                                                                            1                   1.906820e+05
#                                                          exp_scale_pausing 0                   1.913443e+05
#                                                                            1                   1.884248e+05
#                                                          exp_scale_rampup  0                   2.434976e+05
#                                                                            1                   2.323269e+05
#                                                          exp_scale_shaped  0                   1.900646e+05
#                                                                            1                   1.861197e+05
#                     obs_feature_object-storage_full      exp_scale_fixed   0                   2.052473e+05
#                                                                            1                   2.096177e+05
#                                                          exp_scale_pausing 0                   1.809767e+05
#                                                                            1                   1.867683e+05
#                                                          exp_scale_rampup  0                   1.996195e+05
#                                                                            1                   2.117144e+05
#                                                          exp_scale_shaped  0                   1.914488e+05
#                                                                            1                   1.890089e+05
#
#                                                                                           wattage_avg
# exp_start           exp_branch                           exp_workload      run_iteration
# 2024-06-22_11-26-02 baseline_vanilla_full                exp_scale_fixed   0              5511.583333
#                                                                            1              5477.166667
#                                                          exp_scale_pausing 0              5415.935185
#                                                                            1              5606.638889
#                                                          exp_scale_rampup  0              6167.138889
#                                                                            1              6023.166667
#                                                          exp_scale_shaped  0              5289.409524
#                                                                            1              5287.771429
#                     dbopt_feature_db-optimization_full   exp_scale_fixed   0              5674.148148
#                                                                            1              5550.916667
#                                                          exp_scale_pausing 0              5412.666667
#                                                                            1              5572.222222
#                                                          exp_scale_rampup  0              6006.527778
#                                                                            1              5831.037037
#                                                          exp_scale_shaped  0              5292.000000
#                                                                            1              5267.740196
#                     jvm_jvm-impoove_full                 exp_scale_fixed   0              5447.088235
#                                                                            1              5390.914286
#                                                          exp_scale_pausing 0              5362.004630
#                                                                            1              5362.485294
#                                                          exp_scale_rampup  0              6327.452381
#                                                                            1              6048.342857
#                                                          exp_scale_shaped  0              5297.600000
#                                                                            1              5362.233333
#                     lessrec_feature_lessrecs_full        exp_scale_fixed   0              5600.933333
#                                                                            1              5540.419048
#                                                          exp_scale_pausing 0              5550.916667
#                                                                            1              5557.472222
#                                                          exp_scale_rampup  0              6368.722222
#                                                                            1              6394.944444
#                                                          exp_scale_shaped  0              5311.455882
#                                                                            1              5466.323810
#                     norec_feature_norecommendations_full exp_scale_fixed   0              5536.166667
#                                                                            1              5428.000000
#                                                          exp_scale_pausing 0              5668.916667
#                                                                            1              5283.560185
#                                                          exp_scale_rampup  0              6394.944444
#                                                                            1              6088.472222
#                                                          exp_scale_shaped  0              5354.933333
#                                                                            1              5348.380952
#                     obs_feature_object-storage_full      exp_scale_fixed   0              5579.361111
#                                                                            1              5785.277778
#                                                          exp_scale_pausing 0              5340.759259
#                                                                            1              5295.000000
#                                                          exp_scale_rampup  0              5529.611111
#                                                                            1              5816.416667
#                                                          exp_scale_shaped  0              5437.366667
#                                                                            1              5453.700000

# %%
wdf = exr.pods_energy().merge(
    how="left",
    right=exr.run_stats(),
    on=exv2.experiment_results.ExperimentResults.RUN_VARS,
    validate="one_to_one",
)


wdf['ws_per_rq'] = wdf['wattage_kepler'] / wdf['Success Count']
wdf['mems_per_rq'] = wdf['memory_usage'] / wdf['Success Count']
wdf['cpus_per_rq'] = wdf['cpu_usage'] / wdf['Success Count']

wdf.describe()
# Out:
#                       run_time_x  wattage_kepler  wattage_scaph  cpu_usage  \
# count                         24       24.000000      24.000000  24.000000
# mean   0 days 00:05:48.583333333    65793.922419   20935.656880  20.754188
# std    0 days 00:00:05.132307445     9094.051141   91536.868115   6.388431
# min              0 days 00:05:43    49568.700000    1016.111511  13.570261
# 25%              0 days 00:05:44    59815.950000    1619.457750  17.356213
# 50%       0 days 00:05:48.500000    64151.550000    1882.415110  20.158925
# 75%              0 days 00:05:54    69647.904292    2675.471024  22.288583
# max              0 days 00:05:54    83989.877630  450658.946576  46.084394
#
#         memory_usage  wattage_kepler_avg  wattage_scaph_avg  cpu_usage_avg  \
# count      24.000000           24.000000          24.000000      24.000000
# mean   202391.699647        80397.998100       22787.841073      24.956248
# std     69435.413972         8390.788524       98434.747669       4.440043
# min     94579.943424        62021.033663        1191.652370      16.623570
# 25%    161316.914125        74057.758851        2166.062877      22.850370
# 50%    193321.708544        80630.325065        2320.772877      25.033488
# 75%    259955.982848        85291.005080        3420.736104      26.673289
# max    358914.054827        96374.345993      484903.547379      40.068451
#
#        memory_usage_avg  Request Count  Failure Count  Success Count  \
# count         24.000000      24.000000      24.000000      24.000000
# mean      244349.237596    2810.208333     107.166667    2703.041667
# std        66755.448510     252.138675     326.021427     393.205387
# min       116198.216207    1806.000000       1.000000    1518.000000
# 25%       210220.611457    2736.250000       2.750000    2708.000000
# 50%       264274.898807    2842.500000       5.000000    2813.500000
# 75%       299327.303086    2920.500000      16.500000    2907.750000
# max       328582.019072    3183.000000    1237.000000    3066.000000
#
#        reliability                 run_time_y  total_rps  success_rps  \
# count    24.000000                         24  24.000000    24.000000
# mean      0.962189  0 days 00:05:48.583333333   8.061388     7.757377
# std       0.112845  0 days 00:00:05.132307445   0.714877     1.140658
# min       0.582726            0 days 00:05:43   5.265306     4.300283
# 25%       0.994034            0 days 00:05:44   7.839559     7.757768
# 50%       0.998289     0 days 00:05:48.500000   8.207389     8.178779
# 75%       0.999047            0 days 00:05:54   8.466913     8.392495
# max       0.999645            0 days 00:05:54   9.016997     8.685552
#
#        ws_per_rq  mems_per_rq  cpus_per_rq
# count  24.000000    24.000000    24.000000
# mean   25.006639    76.666138     0.007902
# std     5.800570    28.091082     0.002740
# min    17.080875    32.290865     0.004723
# 25%    20.539978    58.219456     0.006050
# 50%    23.691452    73.454631     0.007430
# 75%    27.156614    99.694378     0.008415
# max    40.903096   137.747376     0.015475

# %%
import matplotlib.pyplot as plt
cols = ['ws_per_rq', 'cpus_per_rq', 'mems_per_rq']
# fig, axs = plt.subplots(ncols=3)

# i = 0
# for i, col in enumerate(cols):
#     baseline = wdf[wdf['exp_branch'] == 'baseline_vanilla_full'][col].mean()
#     display(baseline)
#     ax = sns.barplot(data=wdf, hue='exp_branch', y=col, ax=axs[i]) # , hue="exp_workload")
#     ax.axhline(y=baseline)

wdfm = wdf.melt(id_vars=exv2.experiment_results.ExperimentResults.RUN_VARS, value_vars=cols)
wdfm

sns.catplot(
    data=wdfm,
    kind="bar",
    col="variable",
    y="value",
    sharey=False,
    hue="exp_branch",
    palette="rocket",
)

plt.savefig("figs/branch_resources.pdf")

# %% [markdown]
# # Comparing different Wattages measurements + Aggregations for all Nodes
#
# Something is very off....

# %%
# comparing summing up all wattages (assuming they are per second) vs average watt per experiment times number of seconds

node_watts = exr.nodes_energy().reset_index()
wcols = []
# wcols.extend(node_watts.columns[node_watts.columns.str.startswith('wattage')])
wcols.extend(['wattage'])
wcols.extend(node_watts.columns[node_watts.columns.str.endswith('usage')])
display(wcols)

kep = node_watts['wattage_kepler'].sum()
sca = node_watts['wattage_scaph'].sum()
tapo = node_watts['wattage'].sum()

ratio = kep/sca

display(kep, sca, tapo, ratio)

sns.barplot(
    data=node_watts.melt(id_vars=exv2.experiment_results.ExperimentResults.RUN_VARS, value_vars=list(wcols)),
    x="exp_branch",
    y="value",
    hue="variable"
)

node_watts
# Out:
# ['wattage', 'cpu_usage', 'memory_usage']
# np.float64(1233.6948067715794)
# np.float64(38777495.9021)
# np.int64(37822)
# np.float64(3.1814710518859694e-05)
#     exp_start                      exp_branch       exp_workload  \
# 0   example25           baseline_vanilla_full    exp_scale_fixed
# 1   example25           baseline_vanilla_full    exp_scale_fixed
# 2   example25           baseline_vanilla_full  exp_scale_pausing
# 3   example25           baseline_vanilla_full  exp_scale_pausing
# 4   example25           baseline_vanilla_full   exp_scale_shaped
# 5   example25           baseline_vanilla_full   exp_scale_shaped
# 6   example25  monolith_feature_monolith_full    exp_scale_fixed
# 7   example25  monolith_feature_monolith_full    exp_scale_fixed
# 8   example25  monolith_feature_monolith_full  exp_scale_pausing
# 9   example25  monolith_feature_monolith_full  exp_scale_pausing
# 10  example25  monolith_feature_monolith_full   exp_scale_shaped
# 11  example25  monolith_feature_monolith_full   exp_scale_shaped
#
#    run_iteration        run_time  wattage_kepler  wattage_scaph  wattage  \
# 0              0 0 days 00:05:53      107.009392   1.144268e+05     3110
# 1              1 0 days 00:05:54      153.402557   1.231219e+05     3316
# 2              0 0 days 00:05:53      108.497408   1.200162e+05     3324
# 3              1 0 days 00:05:53      108.568884   1.190993e+05     3395
# 4              0 0 days 00:05:43      104.908766   1.147134e+05     3281
# 5              1 0 days 00:05:43      111.722838   1.128031e+05     3327
# 6              0 0 days 00:05:53       83.419860   9.947621e+04     2895
# 7              1 0 days 00:05:43       80.673600   9.938900e+04     2916
# 8              0 0 days 00:05:52       89.725014   1.259076e+07     3039
# 9              1 0 days 00:05:53       85.315648   1.028477e+05     2995
# 10             0 0 days 00:05:42      101.620619   1.258700e+07     3102
# 11             1 0 days 00:05:43       98.830222   1.259384e+07     3122
#
#     cpu_usage  memory_usage  wattage_kepler_avg  wattage_scaph_avg  \
# 0   62.527081     38.471387          185.168212       1.980032e+05
# 1   79.593333     42.537396          258.592882       2.075483e+05
# 2   63.120145     40.587019          177.312894       1.961376e+05
# 3   53.680667     40.790932          177.429705       1.946391e+05
# 4   49.996028     38.042422          171.350984       1.873651e+05
# 5   57.882042     38.635841          182.480635       1.842450e+05
# 6   37.628667     33.091371          140.224812       1.672148e+05
# 7   37.828333     33.078630          131.766880       1.623354e+05
# 8   46.345999     34.040734          146.218541       2.051828e+07
# 9   44.347000     34.077334          139.427888       1.680798e+05
# 10  57.763333     33.666959          165.496436       2.049884e+07
# 11  58.149668     33.782737          161.422695       2.056993e+07
#
#     wattage_avg  cpu_usage_avg  memory_usage_avg
# 0   5381.519608     108.196371         66.570586
# 1   5589.828571     134.171619         71.705897
# 2   5432.277778     103.154681         66.329711
# 3   5548.310185      87.728127         66.662959
# 4   5358.966667      81.660180         62.135956
# 5   5434.100000      94.540669         63.105207
# 6   4866.357143      63.251997         55.625018
# 7   4762.800000      61.786278         54.028429
# 8   4952.444444      75.526814         55.473789
# 9   4894.606481      72.474495         55.691198
# 10  5051.828571      94.071714         54.829047
# 11  5099.266667      94.977791         55.178470

# %% [markdown]
# # Total CPU / Mem

# %%
node_watts = exr.nodes_energy().reset_index()
wcols = []
# wcols.extend(node_watts.columns[node_watts.columns.str.startswith('wattage')])
# wcols.extend(['wattage'])
wcols.extend(node_watts.columns[node_watts.columns.str.contains('usage')])
display(wcols)

kep = node_watts['wattage_kepler'].sum()
sca = node_watts['wattage_scaph'].sum()
tapo = node_watts['wattage'].sum()

ratio = kep/sca

display(kep, sca, tapo, ratio)

sns.barplot(
    data=node_watts.melt(id_vars=exv2.experiment_results.ExperimentResults.RUN_VARS, value_vars=list(wcols)),
    x="variable",
    y="value",
    hue="exp_branch"
)
# Out:
# ['cpu_usage', 'memory_usage', 'cpu_usage_avg', 'memory_usage_avg']
# np.float64(1233.6948067715794)
# np.float64(38777495.9021)
# np.int64(37822)
# np.float64(3.1814710518859694e-05)
# <Axes: xlabel='variable', ylabel='value'>

# %%
exr.stats_history
# Out:
#         timestamp  user_count type  \
# 15     1719335661          15  GET
# 17     1719335662          16  GET
# 19     1719335663          17  GET
# 21     1719335664          18  GET
# 23     1719335665          19  GET
# ...           ...         ...  ...
# 61667  1719331929          20  GET
# 61668  1719331929          20  GET
# 61669  1719331929          20  GET
# 61670  1719331929          20  GET
# 61671  1719331929          20  GET
#
#                                                   url  rq_s  frq_s  rq  frq  \
# 15                   /tools.descartes.teastore.webui/   0.0    0.0  10    2
# 17                   /tools.descartes.teastore.webui/   0.0    0.0  16    2
# 19                   /tools.descartes.teastore.webui/   0.0    0.0  17    2
# 21                   /tools.descartes.teastore.webui/   0.0    0.0  18    2
# 23                   /tools.descartes.teastore.webui/   1.6    0.2  19    2
# ...                                               ...   ...    ...  ..  ...
# 61667  /tools.descartes.teastore.webui/product?id=486   0.0    0.0   1    0
# 61668  /tools.descartes.teastore.webui/product?id=487   0.0    0.0   2    0
# 61669  /tools.descartes.teastore.webui/product?id=488   0.0    0.0   1    0
# 61670  /tools.descartes.teastore.webui/product?id=492   0.0    0.0   1    0
# 61671  /tools.descartes.teastore.webui/product?id=495   0.1    0.0   1    0
#
#        mean_rsp_time  mean_resp_size       exp_workload  \
# 15       8866.842765     8520.600000    exp_scale_fixed
# 17       7531.656221     8664.750000    exp_scale_fixed
# 19       7098.247759     8678.882353    exp_scale_fixed
# 21       6712.487106     8691.444444    exp_scale_fixed
# 23       6362.962513     8702.684211    exp_scale_fixed
# ...              ...             ...                ...
# 61667     315.258571    61695.000000  exp_scale_pausing
# 61668     732.204945    61695.000000  exp_scale_pausing
# 61669     325.395953    80644.000000  exp_scale_pausing
# 61670     214.824565    83821.000000  exp_scale_pausing
# 61671      67.839876    61677.000000  exp_scale_pausing
#
#                            exp_branch  exp_start run_start run_iteration  \
# 15              baseline_vanilla_full  example25                       0
# 17              baseline_vanilla_full  example25                       0
# 19              baseline_vanilla_full  example25                       0
# 21              baseline_vanilla_full  example25                       0
# 23              baseline_vanilla_full  example25                       0
# ...                               ...        ...       ...           ...
# 61667  monolith_feature_monolith_full  example25                       1
# 61668  monolith_feature_monolith_full  example25                       1
# 61669  monolith_feature_monolith_full  example25                       1
# 61670  monolith_feature_monolith_full  example25                       1
# 61671  monolith_feature_monolith_full  example25                       1
#
#                                                      run  \
# 15               baseline_vanilla_full_exp_scale_fixed_0
# 17               baseline_vanilla_full_exp_scale_fixed_0
# 19               baseline_vanilla_full_exp_scale_fixed_0
# 21               baseline_vanilla_full_exp_scale_fixed_0
# 23               baseline_vanilla_full_exp_scale_fixed_0
# ...                                                  ...
# 61667  monolith_feature_monolith_full_exp_scale_pausi...
# 61668  monolith_feature_monolith_full_exp_scale_pausi...
# 61669  monolith_feature_monolith_full_exp_scale_pausi...
# 61670  monolith_feature_monolith_full_exp_scale_pausi...
# 61671  monolith_feature_monolith_full_exp_scale_pausi...
#
#                                                     urun  run_time
# 15     example25_baseline_vanilla_full_exp_scale_fixed_0         0
# 17     example25_baseline_vanilla_full_exp_scale_fixed_0         1
# 19     example25_baseline_vanilla_full_exp_scale_fixed_0         2
# 21     example25_baseline_vanilla_full_exp_scale_fixed_0         3
# 23     example25_baseline_vanilla_full_exp_scale_fixed_0         4
# ...                                                  ...       ...
# 61667  example25_monolith_feature_monolith_full_exp_s...       294
# 61668  example25_monolith_feature_monolith_full_exp_s...       294
# 61669  example25_monolith_feature_monolith_full_exp_s...       294
# 61670  example25_monolith_feature_monolith_full_exp_s...       294
# 61671  example25_monolith_feature_monolith_full_exp_s...       294
#
# [725588 rows x 18 columns]

# %%
# try to combine history and measurements, e.g. for CPU vs. rq/s

exr.pods['run_seconds'] = exr.pods['run_time'].dt.total_seconds()

run_starts = exr.stats_history.groupby(exr.RUN_VARS)['timestamp'].transform("min")
exr.stats_history['run_seconds'] = exr.stats_history['timestamp'] - run_starts
exr.stats_history
# Out:
#         timestamp  user_count type  \
# 15     1719335661          15  GET
# 17     1719335662          16  GET
# 19     1719335663          17  GET
# 21     1719335664          18  GET
# 23     1719335665          19  GET
# ...           ...         ...  ...
# 61667  1719331929          20  GET
# 61668  1719331929          20  GET
# 61669  1719331929          20  GET
# 61670  1719331929          20  GET
# 61671  1719331929          20  GET
#
#                                                   url  rq_s  frq_s  rq  frq  \
# 15                   /tools.descartes.teastore.webui/   0.0    0.0  10    2
# 17                   /tools.descartes.teastore.webui/   0.0    0.0  16    2
# 19                   /tools.descartes.teastore.webui/   0.0    0.0  17    2
# 21                   /tools.descartes.teastore.webui/   0.0    0.0  18    2
# 23                   /tools.descartes.teastore.webui/   1.6    0.2  19    2
# ...                                               ...   ...    ...  ..  ...
# 61667  /tools.descartes.teastore.webui/product?id=486   0.0    0.0   1    0
# 61668  /tools.descartes.teastore.webui/product?id=487   0.0    0.0   2    0
# 61669  /tools.descartes.teastore.webui/product?id=488   0.0    0.0   1    0
# 61670  /tools.descartes.teastore.webui/product?id=492   0.0    0.0   1    0
# 61671  /tools.descartes.teastore.webui/product?id=495   0.1    0.0   1    0
#
#        mean_rsp_time  mean_resp_size       exp_workload  \
# 15       8866.842765     8520.600000    exp_scale_fixed
# 17       7531.656221     8664.750000    exp_scale_fixed
# 19       7098.247759     8678.882353    exp_scale_fixed
# 21       6712.487106     8691.444444    exp_scale_fixed
# 23       6362.962513     8702.684211    exp_scale_fixed
# ...              ...             ...                ...
# 61667     315.258571    61695.000000  exp_scale_pausing
# 61668     732.204945    61695.000000  exp_scale_pausing
# 61669     325.395953    80644.000000  exp_scale_pausing
# 61670     214.824565    83821.000000  exp_scale_pausing
# 61671      67.839876    61677.000000  exp_scale_pausing
#
#                            exp_branch  exp_start run_start run_iteration  \
# 15              baseline_vanilla_full  example25                       0
# 17              baseline_vanilla_full  example25                       0
# 19              baseline_vanilla_full  example25                       0
# 21              baseline_vanilla_full  example25                       0
# 23              baseline_vanilla_full  example25                       0
# ...                               ...        ...       ...           ...
# 61667  monolith_feature_monolith_full  example25                       1
# 61668  monolith_feature_monolith_full  example25                       1
# 61669  monolith_feature_monolith_full  example25                       1
# 61670  monolith_feature_monolith_full  example25                       1
# 61671  monolith_feature_monolith_full  example25                       1
#
#                                                      run  \
# 15               baseline_vanilla_full_exp_scale_fixed_0
# 17               baseline_vanilla_full_exp_scale_fixed_0
# 19               baseline_vanilla_full_exp_scale_fixed_0
# 21               baseline_vanilla_full_exp_scale_fixed_0
# 23               baseline_vanilla_full_exp_scale_fixed_0
# ...                                                  ...
# 61667  monolith_feature_monolith_full_exp_scale_pausi...
# 61668  monolith_feature_monolith_full_exp_scale_pausi...
# 61669  monolith_feature_monolith_full_exp_scale_pausi...
# 61670  monolith_feature_monolith_full_exp_scale_pausi...
# 61671  monolith_feature_monolith_full_exp_scale_pausi...
#
#                                                     urun  run_time  \
# 15     example25_baseline_vanilla_full_exp_scale_fixed_0         0
# 17     example25_baseline_vanilla_full_exp_scale_fixed_0         1
# 19     example25_baseline_vanilla_full_exp_scale_fixed_0         2
# 21     example25_baseline_vanilla_full_exp_scale_fixed_0         3
# 23     example25_baseline_vanilla_full_exp_scale_fixed_0         4
# ...                                                  ...       ...
# 61667  example25_monolith_feature_monolith_full_exp_s...       294
# 61668  example25_monolith_feature_monolith_full_exp_s...       294
# 61669  example25_monolith_feature_monolith_full_exp_s...       294
# 61670  example25_monolith_feature_monolith_full_exp_s...       294
# 61671  example25_monolith_feature_monolith_full_exp_s...       294
#
#        run_seconds
# 15               0
# 17               1
# 19               2
# 21               3
# 23               4
# ...            ...
# 61667          294
# 61668          294
# 61669          294
# 61670          294
# 61671          294
#
# [725588 rows x 19 columns]

# %%
sns.relplot(
    kind="line",
    data=exr.stats_history,
    x="run_time",
    y="rq_s",
    row="exp_branch",
    col="exp_workload",
)

# %%
merged = pd.merge(
    left=exr.pods,
    right=exr.stats_history,
     on="run_seconds"
    )

merged
# Out:
#             collection_time     observation_time                    name  \
# 0       2024-06-25 19:14:14  2024-06-25 19:14:14  teastore-persistence-0
# 1       2024-06-25 19:14:14  2024-06-25 19:14:14  teastore-persistence-0
# 2       2024-06-25 19:14:14  2024-06-25 19:14:14  teastore-persistence-0
# 3       2024-06-25 19:14:14  2024-06-25 19:14:14  teastore-persistence-0
# 4       2024-06-25 19:14:14  2024-06-25 19:14:14  teastore-persistence-0
# ...                     ...                  ...                     ...
# 4594663 2024-06-25 18:12:01  2024-06-25 18:12:01          teastore-all-0
# 4594664 2024-06-25 18:12:01  2024-06-25 18:12:01          teastore-all-0
# 4594665 2024-06-25 18:12:01  2024-06-25 18:12:01          teastore-all-0
# 4594666 2024-06-25 18:12:01  2024-06-25 18:12:01          teastore-all-0
# 4594667 2024-06-25 18:12:01  2024-06-25 18:12:01          teastore-all-0
#
#          namespace  cpu_usage  memory_usage  network_usage    instance  \
# 0        tea-bench   0.580319    646.699008       0.000000      sm-gpu
# 1        tea-bench   0.580319    646.699008       0.000000      sm-gpu
# 2        tea-bench   0.580319    646.699008       0.000000      sm-gpu
# 3        tea-bench   0.580319    646.699008       0.000000      sm-gpu
# 4        tea-bench   0.580319    646.699008       0.000000      sm-gpu
# ...            ...        ...           ...            ...         ...
# 4594663  tea-bench   0.109709   1113.227264       0.002718  ise-knode1
# 4594664  tea-bench   0.109709   1113.227264       0.002718  ise-knode1
# 4594665  tea-bench   0.109709   1113.227264       0.002718  ise-knode1
# 4594666  tea-bench   0.109709   1113.227264       0.002718  ise-knode1
# 4594667  tea-bench   0.109709   1113.227264       0.002718  ise-knode1
#
#          wattage_kepler  wattage_scaph     exp_workload_x  \
# 0                 470.0       0.398842    exp_scale_fixed
# 1                 470.0       0.398842    exp_scale_fixed
# 2                 470.0       0.398842    exp_scale_fixed
# 3                 470.0       0.398842    exp_scale_fixed
# 4                 470.0       0.398842    exp_scale_fixed
# ...                 ...            ...                ...
# 4594663            12.0       0.000665  exp_scale_pausing
# 4594664            12.0       0.000665  exp_scale_pausing
# 4594665            12.0       0.000665  exp_scale_pausing
# 4594666            12.0       0.000665  exp_scale_pausing
# 4594667            12.0       0.000665  exp_scale_pausing
#
#                            exp_branch_x exp_start_x       run_start_x  \
# 0                 baseline_vanilla_full   example25  25_06_2024_19_14
# 1                 baseline_vanilla_full   example25  25_06_2024_19_14
# 2                 baseline_vanilla_full   example25  25_06_2024_19_14
# 3                 baseline_vanilla_full   example25  25_06_2024_19_14
# 4                 baseline_vanilla_full   example25  25_06_2024_19_14
# ...                                 ...         ...               ...
# 4594663  monolith_feature_monolith_full   example25  25_06_2024_18_06
# 4594664  monolith_feature_monolith_full   example25  25_06_2024_18_06
# 4594665  monolith_feature_monolith_full   example25  25_06_2024_18_06
# 4594666  monolith_feature_monolith_full   example25  25_06_2024_18_06
# 4594667  monolith_feature_monolith_full   example25  25_06_2024_18_06
#
#         run_iteration_x                                              run_x  \
# 0                     0            baseline_vanilla_full_exp_scale_fixed_0
# 1                     0            baseline_vanilla_full_exp_scale_fixed_0
# 2                     0            baseline_vanilla_full_exp_scale_fixed_0
# 3                     0            baseline_vanilla_full_exp_scale_fixed_0
# 4                     0            baseline_vanilla_full_exp_scale_fixed_0
# ...                 ...                                                ...
# 4594663               1  monolith_feature_monolith_full_exp_scale_pausi...
# 4594664               1  monolith_feature_monolith_full_exp_scale_pausi...
# 4594665               1  monolith_feature_monolith_full_exp_scale_pausi...
# 4594666               1  monolith_feature_monolith_full_exp_scale_pausi...
# 4594667               1  monolith_feature_monolith_full_exp_scale_pausi...
#
#                                                     urun_x  \
# 0        example25_baseline_vanilla_full_exp_scale_fixed_0
# 1        example25_baseline_vanilla_full_exp_scale_fixed_0
# 2        example25_baseline_vanilla_full_exp_scale_fixed_0
# 3        example25_baseline_vanilla_full_exp_scale_fixed_0
# 4        example25_baseline_vanilla_full_exp_scale_fixed_0
# ...                                                    ...
# 4594663  example25_monolith_feature_monolith_full_exp_s...
# 4594664  example25_monolith_feature_monolith_full_exp_s...
# 4594665  example25_monolith_feature_monolith_full_exp_s...
# 4594666  example25_monolith_feature_monolith_full_exp_s...
# 4594667  example25_monolith_feature_monolith_full_exp_s...
#
#          wattage_kepler_zscore  wattage_scaph_zscore  cpu_usage_zscore  \
# 0                     1.078674              0.993089          2.818917
# 1                     1.078674              0.993089          2.818917
# 2                     1.078674              0.993089          2.818917
# 3                     1.078674              0.993089          2.818917
# 4                     1.078674              0.993089          2.818917
# ...                        ...                   ...               ...
# 4594663              -0.663927             -0.309974          0.160367
# 4594664              -0.663927             -0.309974          0.160367
# 4594665              -0.663927             -0.309974          0.160367
# 4594666              -0.663927             -0.309974          0.160367
# 4594667              -0.663927             -0.309974          0.160367
#
#          memory_usage_zscore  network_usage_zscore      run_time_x  \
# 0                  -0.347763             -0.221994 0 days 00:00:00
# 1                  -0.347763             -0.221994 0 days 00:00:00
# 2                  -0.347763             -0.221994 0 days 00:00:00
# 3                  -0.347763             -0.221994 0 days 00:00:00
# 4                  -0.347763             -0.221994 0 days 00:00:00
# ...                      ...                   ...             ...
# 4594663             1.662318             -0.235603 0 days 00:05:43
# 4594664             1.662318             -0.235603 0 days 00:05:43
# 4594665             1.662318             -0.235603 0 days 00:05:43
# 4594666             1.662318             -0.235603 0 days 00:05:43
# 4594667             1.662318             -0.235603 0 days 00:05:43
#
#                      name_prefix  run_seconds   timestamp  user_count type  \
# 0        [teastore, persistence]          0.0  1719335661          15  GET
# 1        [teastore, persistence]          0.0  1719336094          10  GET
# 2        [teastore, persistence]          0.0  1719332070          65  GET
# 3        [teastore, persistence]          0.0  1719332504          61  GET
# 4        [teastore, persistence]          0.0  1719333035          12  GET
# ...                          ...          ...         ...         ...  ...
# 4594663          [teastore, all]        343.0  1719335562          20  GET
# 4594664          [teastore, all]        343.0  1719335562          20  GET
# 4594665          [teastore, all]        343.0  1719335562          20  GET
# 4594666          [teastore, all]        343.0  1719335562          20  GET
# 4594667          [teastore, all]        343.0  1719335562          20  GET
#
#                                                    url  rq_s  frq_s  rq  frq  \
# 0                     /tools.descartes.teastore.webui/   0.0    0.0  10    2
# 1                     /tools.descartes.teastore.webui/   0.0    0.0   1    1
# 2                     /tools.descartes.teastore.webui/   0.0    0.0  27   17
# 3                     /tools.descartes.teastore.webui/   0.0    0.0  55   18
# 4                                            /category   0.0    0.0   2    2
# ...                                                ...   ...    ...  ..  ...
# 4594663   /tools.descartes.teastore.webui/product?id=8   0.1    0.0   1    0
# 4594664  /tools.descartes.teastore.webui/product?id=81   0.0    0.0   1    0
# 4594665  /tools.descartes.teastore.webui/product?id=84   0.1    0.0   1    0
# 4594666  /tools.descartes.teastore.webui/product?id=95   0.0    0.0   1    0
# 4594667        /tools.descartes.teastore.webui/profile   0.8    0.0  60    0
#
#          mean_rsp_time  mean_resp_size     exp_workload_y  \
# 0          8866.842765     8520.600000    exp_scale_fixed
# 1          5926.113154     6983.000000    exp_scale_fixed
# 2         36495.801695     5838.888889    exp_scale_fixed
# 3         32263.706609     5013.000000    exp_scale_fixed
# 4          5048.661039     7020.000000   exp_scale_shaped
# ...                ...             ...                ...
# 4594663      24.071282    88611.000000  exp_scale_pausing
# 4594664     706.841621    88102.000000  exp_scale_pausing
# 4594665      20.307156    88898.000000  exp_scale_pausing
# 4594666     108.329583    90777.000000  exp_scale_pausing
# 4594667     104.901606     8905.000000  exp_scale_pausing
#
#                            exp_branch_y exp_start_y run_start_y  \
# 0                 baseline_vanilla_full   example25
# 1                 baseline_vanilla_full   example25
# 2        monolith_feature_monolith_full   example25
# 3        monolith_feature_monolith_full   example25
# 4                 baseline_vanilla_full   example25
# ...                                 ...         ...         ...
# 4594663           baseline_vanilla_full   example25
# 4594664           baseline_vanilla_full   example25
# 4594665           baseline_vanilla_full   example25
# 4594666           baseline_vanilla_full   example25
# 4594667           baseline_vanilla_full   example25
#
#         run_iteration_y                                             run_y  \
# 0                     0           baseline_vanilla_full_exp_scale_fixed_0
# 1                     1           baseline_vanilla_full_exp_scale_fixed_1
# 2                     0  monolith_feature_monolith_full_exp_scale_fixed_0
# 3                     1  monolith_feature_monolith_full_exp_scale_fixed_1
# 4                     0          baseline_vanilla_full_exp_scale_shaped_0
# ...                 ...                                               ...
# 4594663               1         baseline_vanilla_full_exp_scale_pausing_1
# 4594664               1         baseline_vanilla_full_exp_scale_pausing_1
# 4594665               1         baseline_vanilla_full_exp_scale_pausing_1
# 4594666               1         baseline_vanilla_full_exp_scale_pausing_1
# 4594667               1         baseline_vanilla_full_exp_scale_pausing_1
#
#                                                     urun_y  run_time_y
# 0        example25_baseline_vanilla_full_exp_scale_fixed_0           0
# 1        example25_baseline_vanilla_full_exp_scale_fixed_1           0
# 2        example25_monolith_feature_monolith_full_exp_s...           0
# 3        example25_monolith_feature_monolith_full_exp_s...           0
# 4        example25_baseline_vanilla_full_exp_scale_shap...           0
# ...                                                    ...         ...
# 4594663  example25_baseline_vanilla_full_exp_scale_paus...         343
# 4594664  example25_baseline_vanilla_full_exp_scale_paus...         343
# 4594665  example25_baseline_vanilla_full_exp_scale_paus...         343
# 4594666  example25_baseline_vanilla_full_exp_scale_paus...         343
# 4594667  example25_baseline_vanilla_full_exp_scale_paus...         343
#
# [4594668 rows x 43 columns]

# %%
mergemelt = merged.melt(
    id_vars=['exp_workload_x', 'exp_branch_x', "run_seconds"],
    value_vars=['cpu_usage', 'rq_s']
)

mergemelt
# Out:
#             exp_workload_x                    exp_branch_x  run_seconds  \
# 0          exp_scale_fixed           baseline_vanilla_full          0.0
# 1          exp_scale_fixed           baseline_vanilla_full          0.0
# 2          exp_scale_fixed           baseline_vanilla_full          0.0
# 3          exp_scale_fixed           baseline_vanilla_full          0.0
# 4          exp_scale_fixed           baseline_vanilla_full          0.0
# ...                    ...                             ...          ...
# 9189331  exp_scale_pausing  monolith_feature_monolith_full        343.0
# 9189332  exp_scale_pausing  monolith_feature_monolith_full        343.0
# 9189333  exp_scale_pausing  monolith_feature_monolith_full        343.0
# 9189334  exp_scale_pausing  monolith_feature_monolith_full        343.0
# 9189335  exp_scale_pausing  monolith_feature_monolith_full        343.0
#
#           variable     value
# 0        cpu_usage  0.580319
# 1        cpu_usage  0.580319
# 2        cpu_usage  0.580319
# 3        cpu_usage  0.580319
# 4        cpu_usage  0.580319
# ...            ...       ...
# 9189331       rq_s  0.100000
# 9189332       rq_s  0.000000
# 9189333       rq_s  0.100000
# 9189334       rq_s  0.000000
# 9189335       rq_s  0.800000
#
# [9189336 rows x 5 columns]

# %%
sns.relplot(
    kind="line",
    data=mergemelt,
    x="run_seconds",
    y="value",
    hue="variable",
    row="exp_branch_x",
    col="exp_workload_x",
)
