# %%
# %load_ext autoreload
# %autoreload 1
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %aimport exv2.experiment_results 

import seaborn as sns
import pandas as pd


pd.set_option('display.max_columns', None)
sns.set_theme(rc={'figure.figsize':(12, 6)})

# %%
MANUAL="data/2024-06-22_11-26-02"
NEW="data/2024-07-12_11-19-47"
# KARL_LOCAL = "data/data/*"
exr = exv2.experiment_results.ExperimentResults(NEW, load_stats_history=True) # type: ignore
RUN_VARS = exv2.experiment_results.ExperimentResults.RUN_VARS # type: ignore

assert("loadgenerator" not in (list(exr.pods['name'].unique())))
assert("unkown" not in (list(exr.pods['instance'].unique())))

display("NODES") # capslock = markdown fuer arme
display(exr.nodes.head())

display("PODS")
display(exr.pods.head())

display("STATS")
display(exr.stats.head())
# Out:
# WARNING:root:loaded 36126 datapoints with 1926 problems
# 'NODES'
#       instance     observation_time     collection_time  cpu_usage  \
# 0       sm-gpu  2024-07-12 11:49:31 2024-07-12 11:49:31   0.233000
# 1   ise-knode3  2024-07-12 11:49:31 2024-07-12 11:49:31   0.039667
# 2   ise-knode1  2024-07-12 11:49:31 2024-07-12 11:49:31   1.431000
# 3   ise-knode6  2024-07-12 11:49:31 2024-07-12 11:49:31   0.283333
# 4  ise-kmaster  2024-07-12 11:49:31 2024-07-12 11:49:31   0.227000
#
#    memory_usage  network_usage  wattage  num_processes  wattage_kepler  \
# 0      0.150242       0.129194       44             14        0.238433
# 1      0.168903       0.006709        0              4        0.000000
# 2      0.218426       0.848995        0             14        1.172467
# 3      0.147404       0.655802       44             23        2.835822
# 4      0.262307       0.348224        0             10        0.000000
#
#    wattage_scaph  wattage_auxilary  temperture      exp_workload  \
# 0      17.023720          0.055387        67.0  exp_scale_rampup
# 1       0.000000          0.000000         0.0  exp_scale_rampup
# 2       1.019892          0.003335         0.0  exp_scale_rampup
# 3      16.038636          0.238929        30.0  exp_scale_rampup
# 4       0.000000          0.000000         0.0  exp_scale_rampup
#
#                            exp_branch            exp_start         run_start  \
# 0  dbopt_feature_db-optimization_full  2024-07-12_11-19-47  12_07_2024_11_49
# 1  dbopt_feature_db-optimization_full  2024-07-12_11-19-47  12_07_2024_11_49
# 2  dbopt_feature_db-optimization_full  2024-07-12_11-19-47  12_07_2024_11_49
# 3  dbopt_feature_db-optimization_full  2024-07-12_11-19-47  12_07_2024_11_49
# 4  dbopt_feature_db-optimization_full  2024-07-12_11-19-47  12_07_2024_11_49
#
#   run_iteration                                                run  \
# 0             1  dbopt_feature_db-optimization_full_exp_scale_r...
# 1             1  dbopt_feature_db-optimization_full_exp_scale_r...
# 2             1  dbopt_feature_db-optimization_full_exp_scale_r...
# 3             1  dbopt_feature_db-optimization_full_exp_scale_r...
# 4             1  dbopt_feature_db-optimization_full_exp_scale_r...
#
#                                                 urun  wattage_kepler_zscore  \
# 0  2024-07-12_11-19-47_dbopt_feature_db-optimizat...              -0.552304
# 1  2024-07-12_11-19-47_dbopt_feature_db-optimizat...              -0.685918
# 2  2024-07-12_11-19-47_dbopt_feature_db-optimizat...              -0.028889
# 3  2024-07-12_11-19-47_dbopt_feature_db-optimizat...               0.903225
# 4  2024-07-12_11-19-47_dbopt_feature_db-optimizat...              -0.685918
#
#    wattage_scaph_zscore  cpu_usage_zscore  memory_usage_zscore  \
# 0              0.966447         -0.790937            -1.489366
# 1             -0.702710         -1.010868            -1.074380
# 2             -0.602711          0.571882             0.026921
# 3              0.869860         -0.733678            -1.552475
# 4             -0.702710         -0.797762             1.002765
#
#    network_usage_zscore run_time  wattage_estimation
# 0             -0.608532   0 days           47.237396
# 1             -0.619124   0 days                 NaN
# 2             -0.546285   0 days                 NaN
# 3             -0.562992   0 days           44.828764
# 4             -0.589591   0 days                 NaN
# 'PODS'
#       collection_time     observation_time                    name  namespace  \
# 0 2024-07-12 11:49:31  2024-07-12 11:49:31  teastore-recommender-0  tea-bench
# 2 2024-07-12 11:49:31  2024-07-12 11:49:31  teastore-persistence-0  tea-bench
# 4 2024-07-12 11:49:31  2024-07-12 11:49:31        teastore-webui-0  tea-bench
# 5 2024-07-12 11:49:31  2024-07-12 11:49:31           teastore-db-0  tea-bench
# 6 2024-07-12 11:49:31  2024-07-12 11:49:31         teastore-auth-0  tea-bench
#
#    cpu_usage  memory_usage  network_usage    instance  wattage_kepler  \
# 0   0.088990    321.003520       0.000787      sm-gpu           382.6
# 2   0.043331    713.986048       0.004165      sm-gpu           382.6
# 4   0.254501   1159.344128       0.000998  ise-knode1            48.4
# 5   0.001590    104.857600       0.001480  ise-knode1            24.2
# 6   0.375946    897.587200       0.000341  ise-knode1            48.4
#
#    wattage_scaph      exp_workload                          exp_branch  \
# 0       0.316701  exp_scale_rampup  dbopt_feature_db-optimization_full
# 2       0.193618  exp_scale_rampup  dbopt_feature_db-optimization_full
# 4       0.034312  exp_scale_rampup  dbopt_feature_db-optimization_full
# 5       0.000107  exp_scale_rampup  dbopt_feature_db-optimization_full
# 6       0.037455  exp_scale_rampup  dbopt_feature_db-optimization_full
#
#              exp_start         run_start run_iteration  \
# 0  2024-07-12_11-19-47  12_07_2024_11_49             1
# 2  2024-07-12_11-19-47  12_07_2024_11_49             1
# 4  2024-07-12_11-19-47  12_07_2024_11_49             1
# 5  2024-07-12_11-19-47  12_07_2024_11_49             1
# 6  2024-07-12_11-19-47  12_07_2024_11_49             1
#
#                                                  run  \
# 0  dbopt_feature_db-optimization_full_exp_scale_r...
# 2  dbopt_feature_db-optimization_full_exp_scale_r...
# 4  dbopt_feature_db-optimization_full_exp_scale_r...
# 5  dbopt_feature_db-optimization_full_exp_scale_r...
# 6  dbopt_feature_db-optimization_full_exp_scale_r...
#
#                                                 urun  wattage_kepler_zscore  \
# 0  2024-07-12_11-19-47_dbopt_feature_db-optimizat...               0.509424
# 2  2024-07-12_11-19-47_dbopt_feature_db-optimizat...               0.509424
# 4  2024-07-12_11-19-47_dbopt_feature_db-optimizat...              -0.893715
# 5  2024-07-12_11-19-47_dbopt_feature_db-optimizat...              -0.995319
# 6  2024-07-12_11-19-47_dbopt_feature_db-optimizat...              -0.893715
#
#    wattage_scaph_zscore  cpu_usage_zscore  memory_usage_zscore  \
# 0             -0.018867         -0.360058            -0.977439
# 2             -0.189093         -0.481460            -0.263896
# 4             -0.409418          0.080011             0.544745
# 5             -0.456725         -0.592442            -1.369897
# 6             -0.405072          0.402917             0.069470
#
#    network_usage_zscore run_time              name_prefix  \
# 0             -0.382285   0 days  [teastore, recommender]
# 2             -0.380862   0 days  [teastore, persistence]
# 4             -0.382196   0 days        [teastore, webui]
# 5             -0.381993   0 days           [teastore, db]
# 6             -0.382473   0 days         [teastore, auth]
#
#                pod_name
# 0  teastore-recommender
# 2  teastore-persistence
# 4        teastore-webui
# 5           teastore-db
# 6         teastore-auth
# 'STATS'
#    Type                                               Name  Request Count  \
# 0   GET                   /tools.descartes.teastore.webui/            170
# 0   GET                   /tools.descartes.teastore.webui/           3167
# 1  POST                   /tools.descartes.teastore.webui/              2
# 2  POST               /tools.descartes.teastore.webui/cart             58
# 3  POST  /tools.descartes.teastore.webui/cartAction?add...              1
#
#    Failure Count  Median Response Time  Average Response Time  \
# 0            170          157000.00000          156057.968360
# 0           2609           16000.00000           33234.302766
# 1              2            2800.00000            4144.874217
# 2             58            3000.00000            3183.572118
# 3              0            1299.88892            1299.888920
#
#    Min Response Time  Max Response Time  Average Content Size  Requests/s  \
# 0       20018.241974      294264.546474              0.000000    0.495096
# 0           1.698060      131072.396711           1306.216609    9.167075
# 1        2761.866807        5527.881626              0.000000    0.005789
# 2         618.340084        6666.404203              0.000000    0.167885
# 3        1299.888920        1299.888920           7788.000000    0.002895
#
#    Failures/s     50%     66%     75%     80%     90%     95%     98%     99%  \
# 0    0.495096  157000  206000  224000  241000  277000  293000  294000  294000
# 0    7.551910   16000   38000   64000   65000   74000  131000  131000  131000
# 1    0.005789    5500    5500    5500    5500    5500    5500    5500    5500
# 2    0.167885    3000    3500    4000    4800    5400    5800    6600    6700
# 3    0.000000    1300    1300    1300    1300    1300    1300    1300    1300
#
#     99.9%  99.99%    100%      exp_workload  \
# 0  294000  294000  294000  exp_scale_rampup
# 0  131000  131000  131000  exp_scale_rampup
# 1    5500    5500    5500  exp_scale_rampup
# 2    6700    6700    6700  exp_scale_rampup
# 3    1300    1300    1300  exp_scale_rampup
#
#                            exp_branch            exp_start run_start  \
# 0  dbopt_feature_db-optimization_full  2024-07-12_11-19-47
# 0     obs_feature_object-storage_full  2024-07-12_11-19-47
# 1     obs_feature_object-storage_full  2024-07-12_11-19-47
# 2     obs_feature_object-storage_full  2024-07-12_11-19-47
# 3     obs_feature_object-storage_full  2024-07-12_11-19-47
#
#   run_iteration                                                run  \
# 0             0  dbopt_feature_db-optimization_full_exp_scale_r...
# 0             1  obs_feature_object-storage_full_exp_scale_ramp...
# 1             1  obs_feature_object-storage_full_exp_scale_ramp...
# 2             1  obs_feature_object-storage_full_exp_scale_ramp...
# 3             1  obs_feature_object-storage_full_exp_scale_ramp...
#
#                                                 urun
# 0  2024-07-12_11-19-47_dbopt_feature_db-optimizat...
# 0  2024-07-12_11-19-47_obs_feature_object-storage...
# 1  2024-07-12_11-19-47_obs_feature_object-storage...
# 2  2024-07-12_11-19-47_obs_feature_object-storage...
# 3  2024-07-12_11-19-47_obs_feature_object-storage...

# %%
exr.pods['exp_workload'].unique()
# Out:
# array(['exp_scale_rampup', 'exp_scale_fixed', 'exp_scale_pausing',
#        'exp_scale_shaped'], dtype=object)

# %%
# comparing summing up all wattages (assuming they are per second) vs average watt per experiment times number of seconds

nrj = exr.pods_energy(energy_workloads=True).reset_index()
wcols = nrj.columns[nrj.columns.str.startswith('wattage')]
wcols

sns.barplot(
    data=nrj.melt(id_vars=exr.RUN_VARS, value_vars=list(wcols)),
    x="exp_workload",
    y="value",
    hue="variable"
)
# Out:
# <Axes: xlabel='exp_workload', ylabel='value'>

# %% [markdown]
# # Scaling Events

# %%
exr.pod_scaling
# Out:
#                                                                                                           wattage_scaph  \
# exp_branch                         exp_workload     pod_name               run_iteration run_time
# baseline_vanilla_full              exp_scale_fixed  teastore-auth          0             0 days 00:00:00       0.275857
#                                                                                          0 days 00:00:10       0.275857
#                                                                            1             0 days 00:00:00       0.778590
#                                                                                          0 days 00:00:10       0.066172
#                                                                                          0 days 00:00:20       0.066172
# ...                                                                                                                 ...
# serverless_feature_serverless_full exp_scale_shaped webhook-57cf8477dc-4cj 1             0 days 00:05:06       0.014382
#                                                                                          0 days 00:05:16       0.014382
#                                                                                          0 days 00:05:26       0.014398
#                                                                                          0 days 00:05:36       0.014398
#                                                                                          0 days 00:05:46       0.014398
#
#                                                                                                           wattage_kepler  \
# exp_branch                         exp_workload     pod_name               run_iteration run_time
# baseline_vanilla_full              exp_scale_fixed  teastore-auth          0             0 days 00:00:00           394.0
#                                                                                          0 days 00:00:10           394.0
#                                                                            1             0 days 00:00:00           472.2
#                                                                                          0 days 00:00:10           196.4
#                                                                                          0 days 00:00:20           196.4
# ...                                                                                                                  ...
# serverless_feature_serverless_full exp_scale_shaped webhook-57cf8477dc-4cj 1             0 days 00:05:06           133.2
#                                                                                          0 days 00:05:16           133.2
#                                                                                          0 days 00:05:26           133.3
#                                                                                          0 days 00:05:36           133.3
#                                                                                          0 days 00:05:46           133.3
#
#                                                                                                           cpu_usage  \
# exp_branch                         exp_workload     pod_name               run_iteration run_time
# baseline_vanilla_full              exp_scale_fixed  teastore-auth          0             0 days 00:00:00   0.082144
#                                                                                          0 days 00:00:10   0.082144
#                                                                            1             0 days 00:00:00   0.226346
#                                                                                          0 days 00:00:10   0.000000
#                                                                                          0 days 00:00:20   0.083108
# ...                                                                                                             ...
# serverless_feature_serverless_full exp_scale_shaped webhook-57cf8477dc-4cj 1             0 days 00:05:06   0.006240
#                                                                                          0 days 00:05:16   0.006240
#                                                                                          0 days 00:05:26   0.006240
#                                                                                          0 days 00:05:36   0.007200
#                                                                                          0 days 00:05:46   0.007200
#
#                                                                                                           name
# exp_branch                         exp_workload     pod_name               run_iteration run_time
# baseline_vanilla_full              exp_scale_fixed  teastore-auth          0             0 days 00:00:00     1
#                                                                                          0 days 00:00:10     1
#                                                                            1             0 days 00:00:00     1
#                                                                                          0 days 00:00:10     2
#                                                                                          0 days 00:00:20     2
# ...                                                                                                        ...
# serverless_feature_serverless_full exp_scale_shaped webhook-57cf8477dc-4cj 1             0 days 00:05:06     1
#                                                                                          0 days 00:05:16     1
#                                                                                          0 days 00:05:26     1
#                                                                                          0 days 00:05:36     1
#                                                                                          0 days 00:05:46     1
#
# [13694 rows x 4 columns]

# %%
RV = ['exp_branch', 'exp_workload', 'run_iteration', 'run_time', ]
pod_sums = exr.pod_scaling.groupby([*RV]).agg({"name": "sum"})
pod_sums
# Out:
#                                                                                    name
# exp_branch                         exp_workload     run_iteration run_time
# baseline_vanilla_full              exp_scale_fixed  0             0 days 00:00:00     8
#                                                                   0 days 00:00:10     8
#                                                     1             0 days 00:00:00     8
#                                                                   0 days 00:00:10     9
#                                                                   0 days 00:00:20     9
# ...                                                                                 ...
# serverless_feature_serverless_full exp_scale_shaped 1             0 days 00:05:06    16
#                                                                   0 days 00:05:16    16
#                                                                   0 days 00:05:26    16
#                                                                   0 days 00:05:36    16
#                                                                   0 days 00:05:46    16
#
# [1855 rows x 1 columns]

# %%
sns.relplot(
    kind="line",
    # data=exr.pod_scaling,
    data=pod_sums,
    x="run_time",
    y="name",
    col="exp_branch",
    row="exp_workload"
)

# %%
pod_sums.index.get_level_values(0)
# Out:
# Index(['exp_scale_fixed', 'exp_scale_fixed', 'exp_scale_fixed',
#        'exp_scale_fixed', 'exp_scale_fixed', 'exp_scale_fixed',
#        'exp_scale_fixed', 'exp_scale_fixed', 'exp_scale_fixed',
#        'exp_scale_fixed',
#        ...
#        'exp_scale_shaped', 'exp_scale_shaped', 'exp_scale_shaped',
#        'exp_scale_shaped', 'exp_scale_shaped', 'exp_scale_shaped',
#        'exp_scale_shaped', 'exp_scale_shaped', 'exp_scale_shaped',
#        'exp_scale_shaped'],
#       dtype='object', name='exp_workload', length=1855)

# %%
# https://stackoverflow.com/questions/60903259/pandas-counting-how-many-times-value-changes-for-a-specific-index
# maybe we need to sub 1
# ps2 = pod_sums.reset_index()
RV2 = ["exp_workload", "exp_branch", "run_iteration"]
# display(ps2)
# pgroups = ps2.groupby(RV2) #
# events = pgroups['name'].diff().ne(0)

# pgroups
#     # .sum() 
#     # .astype(int) \
#     # .reset_index(name="changes")


# pod_sums.groupby(RV2).diff().ne(0).head(100)# pod_sums
pg = pod_sums.groupby(RV2)
pg.diff()

# .nunique()
# Out:
#                                                                                    name
# exp_branch                         exp_workload     run_iteration run_time
# baseline_vanilla_full              exp_scale_fixed  0             0 days 00:00:00   NaN
#                                                                   0 days 00:00:10   0.0
#                                                     1             0 days 00:00:00   NaN
#                                                                   0 days 00:00:10   1.0
#                                                                   0 days 00:00:20   0.0
# ...                                                                                 ...
# serverless_feature_serverless_full exp_scale_shaped 1             0 days 00:05:06   0.0
#                                                                   0 days 00:05:16   0.0
#                                                                   0 days 00:05:26   0.0
#                                                                   0 days 00:05:36   0.0
#                                                                   0 days 00:05:46   0.0
#
# [1855 rows x 1 columns]

# %%
ps3 = exr.pod_scaling
# pg3 = ps3.groupby(['exp_branch', 'exp_workload', 'pod_name', 'run_iteration', 'run_time'])
pd3 = ps3.diff().reset_index()
pd3['Scaling Events'] = pd3['name'].abs()
display(pd3)
pdiffs = pd3.groupby(['exp_branch', 'exp_workload', 'run_iteration']).sum(numeric_only=True)
pdiffs
# Out:
#                                exp_branch      exp_workload  \
# 0                   baseline_vanilla_full   exp_scale_fixed
# 1                   baseline_vanilla_full   exp_scale_fixed
# 2                   baseline_vanilla_full   exp_scale_fixed
# 3                   baseline_vanilla_full   exp_scale_fixed
# 4                   baseline_vanilla_full   exp_scale_fixed
# ...                                   ...               ...
# 13689  serverless_feature_serverless_full  exp_scale_shaped
# 13690  serverless_feature_serverless_full  exp_scale_shaped
# 13691  serverless_feature_serverless_full  exp_scale_shaped
# 13692  serverless_feature_serverless_full  exp_scale_shaped
# 13693  serverless_feature_serverless_full  exp_scale_shaped
#
#                      pod_name run_iteration        run_time  wattage_scaph  \
# 0               teastore-auth             0 0 days 00:00:00            NaN
# 1               teastore-auth             0 0 days 00:00:10       0.000000
# 2               teastore-auth             1 0 days 00:00:00       0.502733
# 3               teastore-auth             1 0 days 00:00:10      -0.712418
# 4               teastore-auth             1 0 days 00:00:20       0.000000
# ...                       ...           ...             ...            ...
# 13689  webhook-57cf8477dc-4cj             1 0 days 00:05:06       0.000000
# 13690  webhook-57cf8477dc-4cj             1 0 days 00:05:16       0.000000
# 13691  webhook-57cf8477dc-4cj             1 0 days 00:05:26       0.000016
# 13692  webhook-57cf8477dc-4cj             1 0 days 00:05:36       0.000000
# 13693  webhook-57cf8477dc-4cj             1 0 days 00:05:46       0.000000
#
#        wattage_kepler  cpu_usage  name  Scaling Events
# 0                 NaN        NaN   NaN             NaN
# 1                 0.0   0.000000   0.0             0.0
# 2                78.2   0.144202   0.0             0.0
# 3              -275.8  -0.226346   1.0             1.0
# 4                 0.0   0.083108   0.0             0.0
# ...               ...        ...   ...             ...
# 13689             0.0   0.006240   0.0             0.0
# 13690             0.0   0.000000   0.0             0.0
# 13691             0.1   0.000000   0.0             0.0
# 13692             0.0   0.000960   0.0             0.0
# 13693             0.0   0.000000   0.0             0.0
#
# [13694 rows x 10 columns]
#                                                                     wattage_scaph  \
# exp_branch                         exp_workload      run_iteration
# baseline_vanilla_full              exp_scale_fixed   0                   0.100286
#                                                      1                  -0.370392
#                                    exp_scale_pausing 0                  -0.016607
#                                                      1                   0.030065
#                                    exp_scale_rampup  0                   1.269331
# ...                                                                           ...
# serverless_feature_serverless_full exp_scale_pausing 1                   0.042026
#                                    exp_scale_rampup  0                   0.208140
#                                                      1                  -0.207203
#                                    exp_scale_shaped  0                   0.032182
#                                                      1                  -0.035027
#
#                                                                     wattage_kepler  \
# exp_branch                         exp_workload      run_iteration
# baseline_vanilla_full              exp_scale_fixed   0                  -61.800000
#                                                      1                 -320.900000
#                                    exp_scale_pausing 0                 -359.800000
#                                                      1                  530.900000
#                                    exp_scale_rampup  0                 -340.333333
# ...                                                                            ...
# serverless_feature_serverless_full exp_scale_pausing 1                 1111.700000
#                                    exp_scale_rampup  0                 1030.200000
#                                                      1                -1035.700000
#                                    exp_scale_shaped  0                  513.366667
#                                                      1                 -508.266667
#
#                                                                     cpu_usage  \
# exp_branch                         exp_workload      run_iteration
# baseline_vanilla_full              exp_scale_fixed   0               0.864323
#                                                      1              -0.235160
#                                    exp_scale_pausing 0              -0.505309
#                                                      1              -0.205998
#                                    exp_scale_rampup  0              -0.104723
# ...                                                                       ...
# serverless_feature_serverless_full exp_scale_pausing 1              -0.170735
#                                    exp_scale_rampup  0              -0.197822
#                                                      1               0.203611
#                                    exp_scale_shaped  0              -0.143805
#                                                      1               0.138602
#
#                                                                     name  \
# exp_branch                         exp_workload      run_iteration
# baseline_vanilla_full              exp_scale_fixed   0               0.0
#                                                      1               1.0
#                                    exp_scale_pausing 0               0.0
#                                                      1               0.0
#                                    exp_scale_rampup  0              -1.0
# ...                                                                  ...
# serverless_feature_serverless_full exp_scale_pausing 1              -1.0
#                                    exp_scale_rampup  0               0.0
#                                                      1               0.0
#                                    exp_scale_shaped  0               0.0
#                                                      1               0.0
#
#                                                                     Scaling Events
# exp_branch                         exp_workload      run_iteration
# baseline_vanilla_full              exp_scale_fixed   0                         2.0
#                                                      1                         1.0
#                                    exp_scale_pausing 0                         4.0
#                                                      1                         0.0
#                                    exp_scale_rampup  0                         7.0
# ...                                                                            ...
# serverless_feature_serverless_full exp_scale_pausing 1                         1.0
#                                    exp_scale_rampup  0                         8.0
#                                                      1                         6.0
#                                    exp_scale_shaped  0                         6.0
#                                                      1                         4.0
#
# [64 rows x 5 columns]

# %%
sns.barplot(
    data=pdiffs,
    x="pod_name",
    y="Scaling Events",
    hue="exp_branch",
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[149], line 1
# ----> 1 sns.barplot(
#       2     data=pdiffs,
#       3     x="pod_name",
#       4     y="Scaling Events",
#       5     hue="exp_branch",
#       6 )
#
# File ~/.local/share/virtualenvs/teastore_experiments-gXtBjM1O/lib/python3.9/site-packages/seaborn/categorical.py:2341, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2338 if estimator is len:
#    2339     estimator = "size"
# -> 2341 p = _CategoricalAggPlotter(
#    2342     data=data,
#    2343     variables=dict(x=x, y=y, hue=hue, units=units, weight=weights),
#    2344     order=order,
#    2345     orient=orient,
#    2346     color=color,
#    2347     legend=legend,
#    2348 )
#    2350 if ax is None:
#    2351     ax = plt.gca()
#
# File ~/.local/share/virtualenvs/teastore_experiments-gXtBjM1O/lib/python3.9/site-packages/seaborn/categorical.py:67, in _CategoricalPlotter.__init__(self, data, variables, order, orient, require_numeric, color, legend)
#      56 def __init__(
#      57     self,
#      58     data=None,
#    (...)
#      64     legend="auto",
#      65 ):
# ---> 67     super().__init__(data=data, variables=variables)
#      69     # This method takes care of some bookkeeping that is necessary because the
#      70     # original categorical plots (prior to the 2021 refactor) had some rules that
#      71     # don't fit exactly into VectorPlotter logic. It may be wise to have a second
#    (...)
#      76     # default VectorPlotter rules. If we do decide to make orient part of the
#      77     # _base variable assignment, we'll want to figure out how to express that.
#      78     if self.input_format == "wide" and orient in ["h", "y"]:
#
# File ~/.local/share/virtualenvs/teastore_experiments-gXtBjM1O/lib/python3.9/site-packages/seaborn/_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File ~/.local/share/virtualenvs/teastore_experiments-gXtBjM1O/lib/python3.9/site-packages/seaborn/_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File ~/.local/share/virtualenvs/teastore_experiments-gXtBjM1O/lib/python3.9/site-packages/seaborn/_core/data.py:58, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
#      57     data = handle_data_source(data)
# ---> 58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#      61     self.names = names
#
# File ~/.local/share/virtualenvs/teastore_experiments-gXtBjM1O/lib/python3.9/site-packages/seaborn/_core/data.py:232, in PlotData._assign_variables(self, data, variables)
#     230     else:
#     231         err += "An entry with this name does not appear in `data`."
# --> 232     raise ValueError(err)
#     234 else:
#     235
#     236     # Otherwise, assume the value somehow represents data
#     237
#     238     # Ignore empty data structures
#     239     if isinstance(val, Sized) and len(val) == 0:
#
# ValueError: Could not interpret value `pod_name` for `x`. An entry with this name does not appear in `data`.

# %%
pdiffs.groupby("pod_name").sum(numeric_only=True)

# sns.lineplot([1,2,3])
# Out:
#                                                     wattage_scaph  \
# pod_name
# activator-f7478b8c4-jhcactivator-f7478b8c4-jhca...      -0.207203
# activator-f7478b8c4-jhcactivator-f7478b8c4-jhca...      -0.437864
# activator-f7478b8c4-jhcactivator-f7478b8c4-jhca...       0.042026
# activator-f7478b8c4-jhcactivator-f7478b8c4-jhca...      -0.040497
# activator-f7478b8c4-jhcactivator-f7478b8c4-jhca...       0.032182
# activator-f7478b8c4-jhcactivator-f7478b8c4-jhca...       0.208140
# activator-f7478b8c4-jhcactivator-f7478b8c4-jhca...      -0.035027
# activator-f7478b8c4-jhcactivator-f7478b8c4-jhca...       0.396874
# teastore-allteastore-allteastore-allteastore-al...      -0.006142
# teastore-allteastore-allteastore-allteastore-al...       0.002219
# teastore-allteastore-allteastore-allteastore-al...      -0.011723
# teastore-authteastore-authteastore-authteastore...       0.056291
# teastore-authteastore-authteastore-authteastore...      -0.000995
# teastore-authteastore-authteastore-authteastore...      -0.141615
# teastore-authteastore-authteastore-authteastore...      -0.616382
# teastore-authteastore-authteastore-authteastore...      -0.096618
# teastore-authteastore-authteastore-authteastore...       0.008677
# teastore-authteastore-authteastore-authteastore...      -2.757385
# teastore-authteastore-authteastore-authteastore...       0.529485
# teastore-authteastore-authteastore-dbteastore-d...       2.080907
# teastore-authteastore-dbteastore-imageteastore-...       0.733191
#
#                                                     wattage_kepler  cpu_usage  \
# pod_name
# activator-f7478b8c4-jhcactivator-f7478b8c4-jhca...    -1035.700000   0.203611
# activator-f7478b8c4-jhcactivator-f7478b8c4-jhca...     -275.700000  -0.516348
# activator-f7478b8c4-jhcactivator-f7478b8c4-jhca...     1111.700000  -0.170735
# activator-f7478b8c4-jhcactivator-f7478b8c4-jhca...    -1110.400000   0.168961
# activator-f7478b8c4-jhcactivator-f7478b8c4-jhca...      513.366667  -0.143805
# activator-f7478b8c4-jhcactivator-f7478b8c4-jhca...     1030.200000  -0.197822
# activator-f7478b8c4-jhcactivator-f7478b8c4-jhca...     -508.266667   0.138602
# activator-f7478b8c4-jhcactivator-f7478b8c4-jhca...      211.500000   0.524737
# teastore-allteastore-allteastore-allteastore-al...        5.300000   0.052019
# teastore-allteastore-allteastore-allteastore-al...        3.700000  -0.010065
# teastore-allteastore-allteastore-allteastore-al...     -176.800000  -0.058262
# teastore-authteastore-authteastore-authteastore...      443.045485   0.079831
# teastore-authteastore-authteastore-authteastore...     -333.613155  -0.027590
# teastore-authteastore-authteastore-authteastore...     -846.333333   1.454982
# teastore-authteastore-authteastore-authteastore...     1837.866667  -2.758025
# teastore-authteastore-authteastore-authteastore...     -964.100000  -0.729262
# teastore-authteastore-authteastore-authteastore...      -25.300000  -0.063658
# teastore-authteastore-authteastore-authteastore...      -86.100000   0.617641
# teastore-authteastore-authteastore-authteastore...     -119.100000   1.472811
# teastore-authteastore-authteastore-dbteastore-d...       54.800000  -0.059022
# teastore-authteastore-dbteastore-imageteastore-...        9.234337  -0.053544
#
#                                                     name  Scaling Events
# pod_name
# activator-f7478b8c4-jhcactivator-f7478b8c4-jhca...   0.0             6.0
# activator-f7478b8c4-jhcactivator-f7478b8c4-jhca...  -1.0             3.0
# activator-f7478b8c4-jhcactivator-f7478b8c4-jhca...  -1.0             1.0
# activator-f7478b8c4-jhcactivator-f7478b8c4-jhca...   1.0             1.0
# activator-f7478b8c4-jhcactivator-f7478b8c4-jhca...   0.0             6.0
# activator-f7478b8c4-jhcactivator-f7478b8c4-jhca...   0.0             8.0
# activator-f7478b8c4-jhcactivator-f7478b8c4-jhca...   0.0             4.0
# activator-f7478b8c4-jhcactivator-f7478b8c4-jhca...   0.0             0.0
# teastore-allteastore-allteastore-allteastore-al...   0.0             0.0
# teastore-allteastore-allteastore-allteastore-al...   0.0             4.0
# teastore-allteastore-allteastore-allteastore-al...  -1.0             1.0
# teastore-authteastore-authteastore-authteastore...   2.0             2.0
# teastore-authteastore-authteastore-authteastore...  -4.0             8.0
# teastore-authteastore-authteastore-authteastore...   2.0            60.0
# teastore-authteastore-authteastore-authteastore...  -1.0            51.0
# teastore-authteastore-authteastore-authteastore...  -1.0            15.0
# teastore-authteastore-authteastore-authteastore...   0.0             0.0
# teastore-authteastore-authteastore-authteastore...   3.0             7.0
# teastore-authteastore-authteastore-authteastore...   1.0             1.0
# teastore-authteastore-authteastore-dbteastore-d...   0.0             6.0
# teastore-authteastore-dbteastore-imageteastore-...   0.0             0.0

# %%
pod_sums
pod_sums['name_before'] = pod_sums['name'].shift()
pod_sums
# Out:
#                                                                                    name  \
# exp_branch                         exp_workload     run_iteration run_time
# baseline_vanilla_full              exp_scale_fixed  0             0 days 00:00:00     8
#                                                                   0 days 00:00:10     8
#                                                     1             0 days 00:00:00     8
#                                                                   0 days 00:00:10     9
#                                                                   0 days 00:00:20     9
# ...                                                                                 ...
# serverless_feature_serverless_full exp_scale_shaped 1             0 days 00:05:06    16
#                                                                   0 days 00:05:16    16
#                                                                   0 days 00:05:26    16
#                                                                   0 days 00:05:36    16
#                                                                   0 days 00:05:46    16
#
#                                                                                    name_before
# exp_branch                         exp_workload     run_iteration run_time
# baseline_vanilla_full              exp_scale_fixed  0             0 days 00:00:00          NaN
#                                                                   0 days 00:00:10          8.0
#                                                     1             0 days 00:00:00          8.0
#                                                                   0 days 00:00:10          8.0
#                                                                   0 days 00:00:20          9.0
# ...                                                                                        ...
# serverless_feature_serverless_full exp_scale_shaped 1             0 days 00:05:06         16.0
#                                                                   0 days 00:05:16         16.0
#                                                                   0 days 00:05:26         16.0
#                                                                   0 days 00:05:36         16.0
#                                                                   0 days 00:05:46         16.0
#
# [1855 rows x 2 columns]

# %%
sns.lineplot(data=exr.nodes[exr.nodes['exp_workload'] == 'exp_scale_fixed'], x='run_time', y='wattage', hue='exp_branch')
# Out:
# <Axes: xlabel='run_time', ylabel='wattage'>

# %% [markdown]
# # Wattage per Request / Resource Consumption

# %%
wdf = exr.pods_energy().merge(
    how="left",
    right=exr.run_stats(),
    on=exr.RUN_VARS,
    validate="one_to_one",
)


wdf['ws_per_rq'] = wdf['wattage_kepler'] / wdf['Success Count']
wdf['mems_per_rq'] = wdf['memory_usage'] / wdf['Success Count']
wdf['cpus_per_rq'] = wdf['cpu_usage'] / wdf['Success Count']

wdf.describe()
# Out:
# /home/basti/.local/share/virtualenvs/teastore_experiments-gXtBjM1O/lib/python3.9/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/basti/.local/share/virtualenvs/teastore_experiments-gXtBjM1O/lib/python3.9/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/basti/.local/share/virtualenvs/teastore_experiments-gXtBjM1O/lib/python3.9/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/basti/.local/share/virtualenvs/teastore_experiments-gXtBjM1O/lib/python3.9/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /home/basti/.local/share/virtualenvs/teastore_experiments-gXtBjM1O/lib/python3.9/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#                       run_time_x  wattage_kepler  wattage_scaph  cpu_usage  \
# count                         32       32.000000      32.000000  32.000000
# mean      0 days 00:03:36.718750    29472.185691     938.108432  10.756543
# std    0 days 00:02:42.449443127    28345.703433    1079.385120   8.690008
# min              0 days 00:00:00     1290.300000       5.269922   0.034592
# 25%              0 days 00:00:30     4609.525000     179.177889   3.140402
# 50%              0 days 00:05:43    22886.512826     528.403293   9.472687
# 75%              0 days 00:05:45    45034.300000    1290.507023  16.945916
# max              0 days 00:06:23    91844.733422    4869.712759  29.890614
#
#         memory_usage  wattage_kepler_avg  wattage_scaph_avg  cpu_usage_avg  \
# count      32.000000           32.000000          32.000000      32.000000
# mean   105916.035102        32233.773027        1052.487355      13.899262
# std    100113.810467        27767.015268        1171.445662      13.495537
# min      2330.966016            0.000000           0.000000       0.000000
# 25%     17560.298496         3601.791667         155.191818       3.240076
# 50%     65174.741675        38159.157575         630.736013      10.518481
# 75%    188724.057600        50221.924840        1699.158672      22.602283
# max    274356.025344        91632.943519        4136.671747      51.015824
#
#        memory_usage_avg  Request Count  Failure Count  Success Count  \
# count         32.000000      30.000000      30.000000      30.000000
# mean      116642.144162    1069.266667      35.400000    1033.866667
# std       101716.485096    1250.824581      50.976398    1272.404396
# min            0.000000      62.000000       1.000000       0.000000
# 25%        13733.646977     165.500000       2.250000      78.750000
# 50%       116124.299062     193.500000       7.000000     182.000000
# 75%       194351.343937    2658.000000      82.750000    2652.500000
# max       304948.790689    2976.000000     170.000000    2971.000000
#
#        reliability                 run_time_y  total_rps  success_rps  \
# count    30.000000                         30  30.000000    30.000000
# mean      0.739796     0 days 00:03:50.500000        inf          inf
# std       0.418646  0 days 00:02:38.323272517        NaN          NaN
# min       0.000000            0 days 00:00:00   0.175637     0.000000
# 25%       0.758797     0 days 00:00:30.250000   1.172664     0.700354
# 50%       0.968215            0 days 00:05:43   6.516667     6.283333
# 75%       0.998107            0 days 00:05:45   8.328875     8.217909
# max       0.999658            0 days 00:06:23        inf          inf
#
#         ws_per_rq  mems_per_rq  cpus_per_rq
# count   30.000000    30.000000    30.000000
# mean          inf          inf          inf
# std           NaN          NaN          NaN
# min      5.467232    12.878265     0.000191
# 25%     15.308609    58.082586     0.007785
# 50%     29.096017    95.918122     0.015012
# 75%    109.400741   368.967386     0.131831
# max           inf          inf          inf

# %%
import matplotlib.pyplot as plt
cols = ['ws_per_rq', 'cpus_per_rq', 'mems_per_rq']
# fig, axs = plt.subplots(ncols=3)

# i = 0
# for i, col in enumerate(cols):
#     baseline = wdf[wdf['exp_branch'] == 'baseline_vanilla_full'][col].mean()
#     display(baseline)
#     ax = sns.barplot(data=wdf, hue='exp_branch', y=col, ax=axs[i]) # , hue="exp_workload")
#     ax.axhline(y=baseline)

wdfm = wdf.melt(id_vars=exr.RUN_VARS, value_vars=cols)
wdfm

g = sns.catplot(
    data=wdfm,
    kind="bar",
    col="variable",
    y="value",
    sharey=False,
    hue="exp_branch",
    palette="rocket",
)

# # baseline magic
for i, col in enumerate(cols):
    baseline = wdf[wdf['exp_branch'] == 'baseline_vanilla_full'][col].mean()
    g.axes[0][i].axhline(baseline, ls="--")


plt.savefig("figs/branch_resources.pdf")

# %% [markdown]
# # Comparing different Wattages measurements + Aggregations for all Nodes
#
# Something is very off....

# %%
# comparing summing up all wattages (assuming they are per second) vs average watt per experiment times number of seconds

node_watts = exr.nodes_energy().reset_index()
wcols = []
# wcols.extend(node_watts.columns[node_watts.columns.str.startswith('wattage')])
wcols.extend(['wattage'])
wcols.extend(node_watts.columns[node_watts.columns.str.endswith('usage')])
# display(wcols)

kep = node_watts['wattage_kepler'].sum()
sca = node_watts['wattage_scaph'].sum()
tapo = node_watts['wattage'].sum()

ratio = kep/sca

display(kep, sca, tapo, ratio)

sns.catplot(
    kind="bar",
    data=node_watts.melt(id_vars=exr.RUN_VARS, value_vars=list(wcols)),
    hue="exp_branch",
    y="value",
    row="variable",
    sharey=False,
)

node_watts
# Out:
# np.float64(2668.6769874516976)
# np.float64(2312213.8285)
# np.int64(64886)
# np.float64(0.0011541653088299995)
#               exp_start                            exp_branch  \
# 0   2024-07-12_11-19-47                 baseline_vanilla_full
# 1   2024-07-12_11-19-47                 baseline_vanilla_full
# 2   2024-07-12_11-19-47                 baseline_vanilla_full
# 3   2024-07-12_11-19-47                 baseline_vanilla_full
# 4   2024-07-12_11-19-47    dbopt_feature_db-optimization_full
# 5   2024-07-12_11-19-47    dbopt_feature_db-optimization_full
# 6   2024-07-12_11-19-47    dbopt_feature_db-optimization_full
# 7   2024-07-12_11-19-47    dbopt_feature_db-optimization_full
# 8   2024-07-12_11-19-47                  jvm_jvm-impoove_full
# 9   2024-07-12_11-19-47                  jvm_jvm-impoove_full
# 10  2024-07-12_11-19-47                  jvm_jvm-impoove_full
# 11  2024-07-12_11-19-47                  jvm_jvm-impoove_full
# 12  2024-07-12_11-19-47         lessrec_feature_lessrecs_full
# 13  2024-07-12_11-19-47         lessrec_feature_lessrecs_full
# 14  2024-07-12_11-19-47         lessrec_feature_lessrecs_full
# 15  2024-07-12_11-19-47         lessrec_feature_lessrecs_full
# 16  2024-07-12_11-19-47        monolith_feature_monolith_full
# 17  2024-07-12_11-19-47        monolith_feature_monolith_full
# 18  2024-07-12_11-19-47        monolith_feature_monolith_full
# 19  2024-07-12_11-19-47        monolith_feature_monolith_full
# 20  2024-07-12_11-19-47  norec_feature_norecommendations_full
# 21  2024-07-12_11-19-47  norec_feature_norecommendations_full
# 22  2024-07-12_11-19-47  norec_feature_norecommendations_full
# 23  2024-07-12_11-19-47  norec_feature_norecommendations_full
# 24  2024-07-12_11-19-47       obs_feature_object-storage_full
# 25  2024-07-12_11-19-47       obs_feature_object-storage_full
# 26  2024-07-12_11-19-47       obs_feature_object-storage_full
# 27  2024-07-12_11-19-47       obs_feature_object-storage_full
# 28  2024-07-12_11-19-47    serverless_feature_serverless_full
# 29  2024-07-12_11-19-47    serverless_feature_serverless_full
# 30  2024-07-12_11-19-47    serverless_feature_serverless_full
# 31  2024-07-12_11-19-47    serverless_feature_serverless_full
#
#         exp_workload run_iteration        run_time  wattage_kepler  \
# 0    exp_scale_fixed             0 0 days 00:00:10        8.886667
# 1    exp_scale_fixed             1 0 days 00:00:30       16.596133
# 2   exp_scale_shaped             0 0 days 00:05:44      133.795267
# 3   exp_scale_shaped             1 0 days 00:05:44      123.164375
# 4    exp_scale_fixed             0 0 days 00:00:30       16.392067
# 5    exp_scale_fixed             1 0 days 00:00:20       14.574600
# 6   exp_scale_shaped             0 0 days 00:06:13      127.532714
# 7   exp_scale_shaped             1 0 days 00:06:23      154.332310
# 8    exp_scale_fixed             0 0 days 00:00:00        3.903033
# 9    exp_scale_fixed             1 0 days 00:05:54      117.371933
# 10  exp_scale_shaped             0 0 days 00:05:45      125.788467
# 11  exp_scale_shaped             1 0 days 00:05:44      126.113667
# 12   exp_scale_fixed             0 0 days 00:00:30       17.919333
# 13   exp_scale_fixed             1 0 days 00:00:30       17.390619
# 14  exp_scale_shaped             0 0 days 00:05:43      120.615367
# 15  exp_scale_shaped             1 0 days 00:05:43      117.078067
# 16   exp_scale_fixed             0 0 days 00:01:00       28.076433
# 17   exp_scale_fixed             1 0 days 00:05:53      136.786033
# 18  exp_scale_shaped             0 0 days 00:05:43      124.856833
# 19  exp_scale_shaped             1 0 days 00:05:43      129.185833
# 20   exp_scale_fixed             0 0 days 00:00:31       15.766029
# 21   exp_scale_fixed             1 0 days 00:00:10       10.199800
# 22  exp_scale_shaped             0 0 days 00:05:44      138.171408
# 23  exp_scale_shaped             1 0 days 00:05:43      119.321600
# 24   exp_scale_fixed             0 0 days 00:00:10        8.702667
# 25   exp_scale_fixed             1 0 days 00:00:31       16.153036
# 26  exp_scale_shaped             0 0 days 00:05:44      114.362533
# 27  exp_scale_shaped             1 0 days 00:05:44      129.524000
# 28   exp_scale_fixed             0 0 days 00:05:46      123.895800
# 29   exp_scale_fixed             1 0 days 00:00:20       11.476233
# 30  exp_scale_shaped             0 0 days 00:05:46      181.153341
# 31  exp_scale_shaped             1 0 days 00:05:46      139.590789
#
#     wattage_scaph  wattage  cpu_usage  memory_usage  wattage_kepler_avg  \
# 0       7024.5102      202   5.570000      2.254068            7.405556
# 1      13861.9795      368   8.972024      4.653233           20.745167
# 2     118472.7664     3237  70.373120     43.026192          219.169389
# 3     104339.1292     3049  58.309027     40.852121          207.688945
# 4      13845.4673      379  10.365687      4.423227           20.490083
# 5      10885.0785      315  10.953000      3.402269           16.194000
# 6     119715.0783     3362  55.662006     43.198493          214.277939
# 7     133908.0456     3712  73.893667     46.585289          252.603737
# 8       3459.7604       93   3.112667      1.057662            0.000000
# 9     112095.6784     3138  44.271333     38.825371          192.359557
# 10    110171.0490     3257  54.695000     38.205459          206.652481
# 11    112354.4060     3203  56.548667     38.240322          206.586197
# 12     13345.7170      353  11.735907      4.464308           22.399167
# 13     12997.5208      372  12.091317      4.545938           21.738274
# 14    111796.6555     3137  48.353742     41.228035          197.005099
# 15    102887.8083     3070  45.100724     39.935921          196.851847
# 16     21370.4552      578   9.716000      7.037689           40.109190
# 17    108307.3386     3041  42.956667     36.674444          223.543842
# 18    112526.4719     3143  59.401000     36.260436          203.932828
# 19    115478.0179     3177  59.115668     36.524520          211.003528
# 20     12958.6269      366   8.345029      4.468979           20.364455
# 21      7761.0646      204   5.526667      2.208586            8.499833
# 22    117772.1461     3236  63.367070     42.723533          226.337925
# 23    109275.9416     3028  43.071033     39.807204          194.891947
# 24      7025.6337      178   3.283288      2.209413            7.252222
# 25     13717.6407      376  10.760667      4.413196           20.864339
# 26    107864.9547     3073  54.900333     39.893709          187.336721
# 27    116822.3558     3227  59.696667     40.802129          212.172648
# 28    113301.8573     3213  48.821338     40.945050          204.133080
# 29     10159.5054      302   5.852333      3.405407           12.751370
# 30    119395.1806     3307  73.341974     42.723134          298.471695
# 31    117315.9871     3190  71.788663     41.875130          236.756926
#
#     wattage_scaph_avg  wattage_avg  cpu_usage_avg  memory_usage_avg
# 0         5853.758500   168.333333       4.641667          1.878390
# 1        17327.474375   460.000000      11.215030          5.816541
# 2       194069.674484  5302.514286     115.277873         70.481000
# 3       175944.413945  5141.450980      98.325026         68.887891
# 4        17306.834125   473.750000      12.957109          5.529034
# 5        12094.531667   350.000000      12.170000          3.780299
# 6       201142.901828  5648.765766      93.522199         72.581251
# 7       219174.279764  6075.623932     120.945617         76.248571
# 8            0.000000     0.000000       0.000000          0.000000
# 9       183712.361822  5142.833333      72.555796         63.630470
# 10      180995.294786  5350.785714      89.856071         62.766112
# 11      184047.217448  5246.819048      92.632102         62.641289
# 12       16682.146250   441.250000      14.669883          5.580385
# 13       16246.901000   465.000000      15.114147          5.682423
# 14      182601.203983  5123.766667      78.977779         67.339124
# 15      172992.736504  5161.813725      75.831119         67.147162
# 16       30529.221714   825.714286      13.880000         10.053842
# 17      177002.270953  4969.782407      70.202330         59.935550
# 18      183793.237437  5133.566667      97.021633         59.225380
# 19      188614.095903  5189.100000      96.555591         59.656716
# 20       16738.226413   472.750000      10.778996          5.772431
# 21        6467.553833   170.000000       4.605556          1.840488
# 22      192921.991707  5300.876190     103.801295         69.985215
# 23      178484.037947  4945.733333      70.349353         65.018434
# 24        5854.694750   148.333333       2.736073          1.841177
# 25       17718.619238   485.666667      13.899194          5.700378
# 26      176693.068651  5033.866667      89.931975         65.349694
# 27      191366.144739  5286.133333      97.788825         66.837774
# 28      186678.298218  5293.800000      80.438966         67.461844
# 29       11288.339333   335.555556       6.502593          3.783785
# 30      196717.773750  5448.676190     120.839633         70.391449
# 31      198977.115375  5410.490196     121.759203         71.023506

# %% [markdown]
# # Total CPU / Mem

# %%
node_watts = exr.nodes_energy().reset_index()
wcols = []
# wcols.extend(node_watts.columns[node_watts.columns.str.startswith('wattage')])
# wcols.extend(['wattage'])
wcols.extend(node_watts.columns[node_watts.columns.str.contains('usage')])
display(wcols)

kep = node_watts['wattage_kepler'].sum()
sca = node_watts['wattage_scaph'].sum()
tapo = node_watts['wattage'].sum()

ratio = kep/sca

display(kep, sca, tapo, ratio)

sns.barplot(
    data=node_watts.melt(id_var=exr.RUN_VARS, value_vars=list(wcols)),
    x="variable",
    y="value",
    hue="exp_branch"
)
# Out:
# ['cpu_usage', 'memory_usage', 'cpu_usage_avg', 'memory_usage_avg']
# np.float64(1233.6948067715794)
# np.float64(38777495.9021)
# np.int64(37822)
# np.float64(3.1814710518859694e-05)
# <Axes: xlabel='variable', ylabel='value'>

# %%
exr.stats_history
# Out:
#         timestamp  user_count type  \
# 15     1719335661          15  GET
# 17     1719335662          16  GET
# 19     1719335663          17  GET
# 21     1719335664          18  GET
# 23     1719335665          19  GET
# ...           ...         ...  ...
# 61667  1719331929          20  GET
# 61668  1719331929          20  GET
# 61669  1719331929          20  GET
# 61670  1719331929          20  GET
# 61671  1719331929          20  GET
#
#                                                   url  rq_s  frq_s  rq  frq  \
# 15                   /tools.descartes.teastore.webui/   0.0    0.0  10    2
# 17                   /tools.descartes.teastore.webui/   0.0    0.0  16    2
# 19                   /tools.descartes.teastore.webui/   0.0    0.0  17    2
# 21                   /tools.descartes.teastore.webui/   0.0    0.0  18    2
# 23                   /tools.descartes.teastore.webui/   1.6    0.2  19    2
# ...                                               ...   ...    ...  ..  ...
# 61667  /tools.descartes.teastore.webui/product?id=486   0.0    0.0   1    0
# 61668  /tools.descartes.teastore.webui/product?id=487   0.0    0.0   2    0
# 61669  /tools.descartes.teastore.webui/product?id=488   0.0    0.0   1    0
# 61670  /tools.descartes.teastore.webui/product?id=492   0.0    0.0   1    0
# 61671  /tools.descartes.teastore.webui/product?id=495   0.1    0.0   1    0
#
#        mean_rsp_time  mean_resp_size       exp_workload  \
# 15       8866.842765     8520.600000    exp_scale_fixed
# 17       7531.656221     8664.750000    exp_scale_fixed
# 19       7098.247759     8678.882353    exp_scale_fixed
# 21       6712.487106     8691.444444    exp_scale_fixed
# 23       6362.962513     8702.684211    exp_scale_fixed
# ...              ...             ...                ...
# 61667     315.258571    61695.000000  exp_scale_pausing
# 61668     732.204945    61695.000000  exp_scale_pausing
# 61669     325.395953    80644.000000  exp_scale_pausing
# 61670     214.824565    83821.000000  exp_scale_pausing
# 61671      67.839876    61677.000000  exp_scale_pausing
#
#                            exp_branch  exp_start run_start run_iteration  \
# 15              baseline_vanilla_full  example25                       0
# 17              baseline_vanilla_full  example25                       0
# 19              baseline_vanilla_full  example25                       0
# 21              baseline_vanilla_full  example25                       0
# 23              baseline_vanilla_full  example25                       0
# ...                               ...        ...       ...           ...
# 61667  monolith_feature_monolith_full  example25                       1
# 61668  monolith_feature_monolith_full  example25                       1
# 61669  monolith_feature_monolith_full  example25                       1
# 61670  monolith_feature_monolith_full  example25                       1
# 61671  monolith_feature_monolith_full  example25                       1
#
#                                                      run  \
# 15               baseline_vanilla_full_exp_scale_fixed_0
# 17               baseline_vanilla_full_exp_scale_fixed_0
# 19               baseline_vanilla_full_exp_scale_fixed_0
# 21               baseline_vanilla_full_exp_scale_fixed_0
# 23               baseline_vanilla_full_exp_scale_fixed_0
# ...                                                  ...
# 61667  monolith_feature_monolith_full_exp_scale_pausi...
# 61668  monolith_feature_monolith_full_exp_scale_pausi...
# 61669  monolith_feature_monolith_full_exp_scale_pausi...
# 61670  monolith_feature_monolith_full_exp_scale_pausi...
# 61671  monolith_feature_monolith_full_exp_scale_pausi...
#
#                                                     urun  run_time
# 15     example25_baseline_vanilla_full_exp_scale_fixed_0         0
# 17     example25_baseline_vanilla_full_exp_scale_fixed_0         1
# 19     example25_baseline_vanilla_full_exp_scale_fixed_0         2
# 21     example25_baseline_vanilla_full_exp_scale_fixed_0         3
# 23     example25_baseline_vanilla_full_exp_scale_fixed_0         4
# ...                                                  ...       ...
# 61667  example25_monolith_feature_monolith_full_exp_s...       294
# 61668  example25_monolith_feature_monolith_full_exp_s...       294
# 61669  example25_monolith_feature_monolith_full_exp_s...       294
# 61670  example25_monolith_feature_monolith_full_exp_s...       294
# 61671  example25_monolith_feature_monolith_full_exp_s...       294
#
# [725588 rows x 18 columns]

# %%
# try to combine history and measurements, e.g. for CPU vs. rq/s

exr.pods['run_seconds'] = exr.pods['run_time'].dt.total_seconds()

run_starts = exr.stats_history.groupby(exr.RUN_VARS)['timestamp'].transform("min")
exr.stats_history['run_seconds'] = exr.stats_history['timestamp'] - run_starts

def round_down_to_nearest(self, n):
    return (self // n) * n

pd.Series.round_down_to_nearest = round_down_to_nearest

exr.stats_history['run5s'] = exr.stats_history['run_time'].round_down_to_nearest(5)
exr.stats_history

runhist = exr.stats_history.groupby([*exr.RUN_VARS, 'run5s']).agg({
    "rq": "sum",
})

# %%
sns.relplot(
    kind="line",
    data=runhist,
    x="run5s",
    y="rq",
    row="exp_branch",
    col="exp_workload",
)

# %%
merged = pd.merge(
    left=exr.pods,
    right=exr.stats_history,
     on="run_seconds"
    )

merged
# Out:
#             collection_time     observation_time                    name  \
# 0       2024-06-25 19:14:14  2024-06-25 19:14:14  teastore-persistence-0
# 1       2024-06-25 19:14:14  2024-06-25 19:14:14  teastore-persistence-0
# 2       2024-06-25 19:14:14  2024-06-25 19:14:14  teastore-persistence-0
# 3       2024-06-25 19:14:14  2024-06-25 19:14:14  teastore-persistence-0
# 4       2024-06-25 19:14:14  2024-06-25 19:14:14  teastore-persistence-0
# ...                     ...                  ...                     ...
# 4594663 2024-06-25 18:12:01  2024-06-25 18:12:01          teastore-all-0
# 4594664 2024-06-25 18:12:01  2024-06-25 18:12:01          teastore-all-0
# 4594665 2024-06-25 18:12:01  2024-06-25 18:12:01          teastore-all-0
# 4594666 2024-06-25 18:12:01  2024-06-25 18:12:01          teastore-all-0
# 4594667 2024-06-25 18:12:01  2024-06-25 18:12:01          teastore-all-0
#
#          namespace  cpu_usage  memory_usage  network_usage    instance  \
# 0        tea-bench   0.580319    646.699008       0.000000      sm-gpu
# 1        tea-bench   0.580319    646.699008       0.000000      sm-gpu
# 2        tea-bench   0.580319    646.699008       0.000000      sm-gpu
# 3        tea-bench   0.580319    646.699008       0.000000      sm-gpu
# 4        tea-bench   0.580319    646.699008       0.000000      sm-gpu
# ...            ...        ...           ...            ...         ...
# 4594663  tea-bench   0.109709   1113.227264       0.002718  ise-knode1
# 4594664  tea-bench   0.109709   1113.227264       0.002718  ise-knode1
# 4594665  tea-bench   0.109709   1113.227264       0.002718  ise-knode1
# 4594666  tea-bench   0.109709   1113.227264       0.002718  ise-knode1
# 4594667  tea-bench   0.109709   1113.227264       0.002718  ise-knode1
#
#          wattage_kepler  wattage_scaph     exp_workload_x  \
# 0                 470.0       0.398842    exp_scale_fixed
# 1                 470.0       0.398842    exp_scale_fixed
# 2                 470.0       0.398842    exp_scale_fixed
# 3                 470.0       0.398842    exp_scale_fixed
# 4                 470.0       0.398842    exp_scale_fixed
# ...                 ...            ...                ...
# 4594663            12.0       0.000665  exp_scale_pausing
# 4594664            12.0       0.000665  exp_scale_pausing
# 4594665            12.0       0.000665  exp_scale_pausing
# 4594666            12.0       0.000665  exp_scale_pausing
# 4594667            12.0       0.000665  exp_scale_pausing
#
#                            exp_branch_x exp_start_x       run_start_x  \
# 0                 baseline_vanilla_full   example25  25_06_2024_19_14
# 1                 baseline_vanilla_full   example25  25_06_2024_19_14
# 2                 baseline_vanilla_full   example25  25_06_2024_19_14
# 3                 baseline_vanilla_full   example25  25_06_2024_19_14
# 4                 baseline_vanilla_full   example25  25_06_2024_19_14
# ...                                 ...         ...               ...
# 4594663  monolith_feature_monolith_full   example25  25_06_2024_18_06
# 4594664  monolith_feature_monolith_full   example25  25_06_2024_18_06
# 4594665  monolith_feature_monolith_full   example25  25_06_2024_18_06
# 4594666  monolith_feature_monolith_full   example25  25_06_2024_18_06
# 4594667  monolith_feature_monolith_full   example25  25_06_2024_18_06
#
#         run_iteration_x                                              run_x  \
# 0                     0            baseline_vanilla_full_exp_scale_fixed_0
# 1                     0            baseline_vanilla_full_exp_scale_fixed_0
# 2                     0            baseline_vanilla_full_exp_scale_fixed_0
# 3                     0            baseline_vanilla_full_exp_scale_fixed_0
# 4                     0            baseline_vanilla_full_exp_scale_fixed_0
# ...                 ...                                                ...
# 4594663               1  monolith_feature_monolith_full_exp_scale_pausi...
# 4594664               1  monolith_feature_monolith_full_exp_scale_pausi...
# 4594665               1  monolith_feature_monolith_full_exp_scale_pausi...
# 4594666               1  monolith_feature_monolith_full_exp_scale_pausi...
# 4594667               1  monolith_feature_monolith_full_exp_scale_pausi...
#
#                                                     urun_x  \
# 0        example25_baseline_vanilla_full_exp_scale_fixed_0
# 1        example25_baseline_vanilla_full_exp_scale_fixed_0
# 2        example25_baseline_vanilla_full_exp_scale_fixed_0
# 3        example25_baseline_vanilla_full_exp_scale_fixed_0
# 4        example25_baseline_vanilla_full_exp_scale_fixed_0
# ...                                                    ...
# 4594663  example25_monolith_feature_monolith_full_exp_s...
# 4594664  example25_monolith_feature_monolith_full_exp_s...
# 4594665  example25_monolith_feature_monolith_full_exp_s...
# 4594666  example25_monolith_feature_monolith_full_exp_s...
# 4594667  example25_monolith_feature_monolith_full_exp_s...
#
#          wattage_kepler_zscore  wattage_scaph_zscore  cpu_usage_zscore  \
# 0                     1.078674              0.993089          2.818917
# 1                     1.078674              0.993089          2.818917
# 2                     1.078674              0.993089          2.818917
# 3                     1.078674              0.993089          2.818917
# 4                     1.078674              0.993089          2.818917
# ...                        ...                   ...               ...
# 4594663              -0.663927             -0.309974          0.160367
# 4594664              -0.663927             -0.309974          0.160367
# 4594665              -0.663927             -0.309974          0.160367
# 4594666              -0.663927             -0.309974          0.160367
# 4594667              -0.663927             -0.309974          0.160367
#
#          memory_usage_zscore  network_usage_zscore      run_time_x  \
# 0                  -0.347763             -0.221994 0 days 00:00:00
# 1                  -0.347763             -0.221994 0 days 00:00:00
# 2                  -0.347763             -0.221994 0 days 00:00:00
# 3                  -0.347763             -0.221994 0 days 00:00:00
# 4                  -0.347763             -0.221994 0 days 00:00:00
# ...                      ...                   ...             ...
# 4594663             1.662318             -0.235603 0 days 00:05:43
# 4594664             1.662318             -0.235603 0 days 00:05:43
# 4594665             1.662318             -0.235603 0 days 00:05:43
# 4594666             1.662318             -0.235603 0 days 00:05:43
# 4594667             1.662318             -0.235603 0 days 00:05:43
#
#                      name_prefix  run_seconds   timestamp  user_count type  \
# 0        [teastore, persistence]          0.0  1719335661          15  GET
# 1        [teastore, persistence]          0.0  1719336094          10  GET
# 2        [teastore, persistence]          0.0  1719332070          65  GET
# 3        [teastore, persistence]          0.0  1719332504          61  GET
# 4        [teastore, persistence]          0.0  1719333035          12  GET
# ...                          ...          ...         ...         ...  ...
# 4594663          [teastore, all]        343.0  1719335562          20  GET
# 4594664          [teastore, all]        343.0  1719335562          20  GET
# 4594665          [teastore, all]        343.0  1719335562          20  GET
# 4594666          [teastore, all]        343.0  1719335562          20  GET
# 4594667          [teastore, all]        343.0  1719335562          20  GET
#
#                                                    url  rq_s  frq_s  rq  frq  \
# 0                     /tools.descartes.teastore.webui/   0.0    0.0  10    2
# 1                     /tools.descartes.teastore.webui/   0.0    0.0   1    1
# 2                     /tools.descartes.teastore.webui/   0.0    0.0  27   17
# 3                     /tools.descartes.teastore.webui/   0.0    0.0  55   18
# 4                                            /category   0.0    0.0   2    2
# ...                                                ...   ...    ...  ..  ...
# 4594663   /tools.descartes.teastore.webui/product?id=8   0.1    0.0   1    0
# 4594664  /tools.descartes.teastore.webui/product?id=81   0.0    0.0   1    0
# 4594665  /tools.descartes.teastore.webui/product?id=84   0.1    0.0   1    0
# 4594666  /tools.descartes.teastore.webui/product?id=95   0.0    0.0   1    0
# 4594667        /tools.descartes.teastore.webui/profile   0.8    0.0  60    0
#
#          mean_rsp_time  mean_resp_size     exp_workload_y  \
# 0          8866.842765     8520.600000    exp_scale_fixed
# 1          5926.113154     6983.000000    exp_scale_fixed
# 2         36495.801695     5838.888889    exp_scale_fixed
# 3         32263.706609     5013.000000    exp_scale_fixed
# 4          5048.661039     7020.000000   exp_scale_shaped
# ...                ...             ...                ...
# 4594663      24.071282    88611.000000  exp_scale_pausing
# 4594664     706.841621    88102.000000  exp_scale_pausing
# 4594665      20.307156    88898.000000  exp_scale_pausing
# 4594666     108.329583    90777.000000  exp_scale_pausing
# 4594667     104.901606     8905.000000  exp_scale_pausing
#
#                            exp_branch_y exp_start_y run_start_y  \
# 0                 baseline_vanilla_full   example25
# 1                 baseline_vanilla_full   example25
# 2        monolith_feature_monolith_full   example25
# 3        monolith_feature_monolith_full   example25
# 4                 baseline_vanilla_full   example25
# ...                                 ...         ...         ...
# 4594663           baseline_vanilla_full   example25
# 4594664           baseline_vanilla_full   example25
# 4594665           baseline_vanilla_full   example25
# 4594666           baseline_vanilla_full   example25
# 4594667           baseline_vanilla_full   example25
#
#         run_iteration_y                                             run_y  \
# 0                     0           baseline_vanilla_full_exp_scale_fixed_0
# 1                     1           baseline_vanilla_full_exp_scale_fixed_1
# 2                     0  monolith_feature_monolith_full_exp_scale_fixed_0
# 3                     1  monolith_feature_monolith_full_exp_scale_fixed_1
# 4                     0          baseline_vanilla_full_exp_scale_shaped_0
# ...                 ...                                               ...
# 4594663               1         baseline_vanilla_full_exp_scale_pausing_1
# 4594664               1         baseline_vanilla_full_exp_scale_pausing_1
# 4594665               1         baseline_vanilla_full_exp_scale_pausing_1
# 4594666               1         baseline_vanilla_full_exp_scale_pausing_1
# 4594667               1         baseline_vanilla_full_exp_scale_pausing_1
#
#                                                     urun_y  run_time_y
# 0        example25_baseline_vanilla_full_exp_scale_fixed_0           0
# 1        example25_baseline_vanilla_full_exp_scale_fixed_1           0
# 2        example25_monolith_feature_monolith_full_exp_s...           0
# 3        example25_monolith_feature_monolith_full_exp_s...           0
# 4        example25_baseline_vanilla_full_exp_scale_shap...           0
# ...                                                    ...         ...
# 4594663  example25_baseline_vanilla_full_exp_scale_paus...         343
# 4594664  example25_baseline_vanilla_full_exp_scale_paus...         343
# 4594665  example25_baseline_vanilla_full_exp_scale_paus...         343
# 4594666  example25_baseline_vanilla_full_exp_scale_paus...         343
# 4594667  example25_baseline_vanilla_full_exp_scale_paus...         343
#
# [4594668 rows x 43 columns]

# %%
mergemelt = merged.melt(
    id_vars=['exp_workload_x', 'exp_branch_x', "run_seconds"],
    value_vars=['cpu_usage', 'rq_s']
)

mergemelt
# Out:
#             exp_workload_x                    exp_branch_x  run_seconds  \
# 0          exp_scale_fixed           baseline_vanilla_full          0.0
# 1          exp_scale_fixed           baseline_vanilla_full          0.0
# 2          exp_scale_fixed           baseline_vanilla_full          0.0
# 3          exp_scale_fixed           baseline_vanilla_full          0.0
# 4          exp_scale_fixed           baseline_vanilla_full          0.0
# ...                    ...                             ...          ...
# 9189331  exp_scale_pausing  monolith_feature_monolith_full        343.0
# 9189332  exp_scale_pausing  monolith_feature_monolith_full        343.0
# 9189333  exp_scale_pausing  monolith_feature_monolith_full        343.0
# 9189334  exp_scale_pausing  monolith_feature_monolith_full        343.0
# 9189335  exp_scale_pausing  monolith_feature_monolith_full        343.0
#
#           variable     value
# 0        cpu_usage  0.580319
# 1        cpu_usage  0.580319
# 2        cpu_usage  0.580319
# 3        cpu_usage  0.580319
# 4        cpu_usage  0.580319
# ...            ...       ...
# 9189331       rq_s  0.100000
# 9189332       rq_s  0.000000
# 9189333       rq_s  0.100000
# 9189334       rq_s  0.000000
# 9189335       rq_s  0.800000
#
# [9189336 rows x 5 columns]

# %%
sns.relplot(
    kind="line",
    data=mergemelt,
    x="run_seconds",
    y="value",
    hue="variable",
    row="exp_branch_x",
    col="exp_workload_x",
)
